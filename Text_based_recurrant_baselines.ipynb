# %% [markdown]
# # Preprocessing the Data

# %%
from tqdm import tqdm_notebook as tqdm
import preprocessor as p
import numpy as np
import json

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.optim as optim
import torch.nn.functional as F

# %%
from collections import Counter
from tqdm import tqdm, tqdm_notebook, tnrange
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

# %%
import matplotlib.pyplot as plt
import random
import pickle as pkl

# %%
dataset = 'twitter16'
    
if dataset == 'twitter15':
    # %run ../twitter15/twitter15_text_processing.ipynb
    with open('./kfolds_twitter15.pickle','rb') as f:
        kfold_df = pkl.load(f)
    datadir = './twitter15_kfold_results/'
    
if dataset == 'twitter16':
    # %run ../twitter16/twitter16_text_processing.ipynb
    with open('./kfolds_twitter16.pickle','rb') as f:
        kfold_df = pkl.load(f)
    datadir = './twitter16_kfold_results/'

# %%
def preprocess(text):
    p.set_options(p.OPT.URL,p.OPT.MENTION,p.OPT.EMOJI,p.OPT.HASHTAG)
    return p.tokenize(text).split()

# %%
twitter15_text
# Out:
# {656955120626880512: 'correct predictions in back to the future ii URL',
#  615689290706595840: ".@whitehouse in rainbow colors for #scotusmarriage? here's what i think about that decision: URL",
#  613404935003217920: 'cops bought the alleged church shooter burger king hours after killings URL',
#  731166399389962242: '🔥ca kkk grand wizard 🔥 endorses @hillaryclinton #neverhillary #trump2016 URL',
#  714598641827246081: 'an open letter to trump voters from his top strategist-turned-defector URL via @xojanedotcom',
#  614467824313106432: 'god put a rainbow over the white house 🌈 URL',
#  715515982584881152: 'craigslist ad: ‘get paid $15 an hour to protest at the trump rally’ - URL URL',
#  693315824132685824: '#quasimodo: dog with short spine has big heart URL URL',
#  693843042546106369: 'need to #getcovered? most people can find a health insurance plan for as little as $75/mo: URL URL',
#  622891631293935616: '#wakeupamerica🇺🇸 who needs a #gun registry when #obama has all your personal information URL URL',
#  692630756548591616: "japan's economy minister akira amari resigns over corruption allegations URL",
#  693265096278163456: 'german shepherd with a rare spinal condition looking for a forever home. URL URL',
#  553589051044151296: 'several hostages freed at jewish supermarket in paris. photo thomas samson #afp URL',
#  553590835850514433: 'hostage-taker in supermarket siege killed, reports say. #parisattacks URL URL',
#  622858454949040128: 'in heaven chick-fil-a is open on sundays.',
#  656870311057575936: 'the 5 most accurate predictions from the decade-jumping adventures in #backtothefuture: URL URL',
#  616311563071434753: "apologies if you've already seen a crow riding a bald eagle today. image: phoo chan story: URL URL",
#  641666167992647681: 'oh, you invented the pencil? #appleevent URL',
#  525060425184858112: "the canadian soldier killed in today's ottawa shooting is cpl. nathan cirillo, a family source told cnn. live blog: URL",
#  672513234419638273: '"thoughts and prayers are not enough." pres. obama speaks on mass shootings over the years: URL URL',
#  544382892378714113: 'five hostages escape sydney cafe siege — live updates from @buzzfeedoz URL URL',
#  681824512120324096: 'when she heard about south korean "comfort women," @yunghi photographed some survivors URL URL',
#  620835698514464768: 'translucent butterfly - beautiful! URL',
#  626898253900943360: 'everyone mad at bruce for his sex change but no one gave ashit about that nerd minkus changing into chanel west coast URL',
#  618804516578680832: "family: @schwarzenegger's last act as governor stole justice from dead son. URL URL",
#  672632899921833984: 'why have there been more mass shootings under obama than the 4 previous presidents combined? URL URL',
#  553588178687655936: 'reports: #charliehebdo suspects killed URL',
#  594687353937100801: 'the kissing islands, greenland. URL',
#  613016993692798977: 'police chief says dylann roof was taken to burger king shortly after arrest URL',
#  663385747177775105: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  766715993385267201: 'russian olympic officials concerned after learning team’s clean urine reservoir almost empty URL URL',
#  693141729529184256: "it's 2016. women should earn the same pay as men for doing the same work. URL #equalpay URL",
#  524966904885428226: 'breaking update: canadian soldier injured at parliament hill shooting dies URL #ottawa',
#  613393657161510913: 'cops bought burger king for dylann roof following his arrest URL URL',
#  544374511194632192: 'update: total of 5 people have been able to get out of sydney cafe during hostage situation: URL URL',
#  706665777332621314: '.@berniesanders: in 2016, "we will end institutional racism and reform a broken criminal justice system.” #demdebate',
#  693827886021767169: '"our high school graduation rate is at an all-time high." —@potus URL URL',
#  604354747357859842: 'florida couple arrested for selling fake real estate on the moon #wtf15 👉🏿👉 URL URL',
#  767709416879644672: '"i hate writing; i love having written." dorothy parker was born on this day in 1893: URL',
#  693146363685642240: "watch one direction's original #xfactoruk auditions from 2010, where it all began URL URL",
#  652783670370115585: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  674187250792558592: 'donald trump v adolf hitler URL',
#  726043971911213057: 'target boycott crosses 1 million signers, stock sinks by $1.5 billion URL',
#  524935485370929152: 'shooting in canadian parliament comes day after isis-inspired radical drove in2 canadian soldier. also reports of shooting at war memorial/1',
#  730939370765754368: 'ca grand dragon endorses hillary clinton on behalf of the kkk. #trump2016 URL URL',
#  723365789378584578: 'landmarks around world turn purple, in honor of #prince. #princerip #purplerain URL',
#  674244561519161344: '"you\'re increasingly compared to hitler. does that bother you?" trump: "no." URL',
#  553535829017370625: '#breaking - at least five hostages in paris kosher supermarket: (afp) URL #vincennes URL',
#  731093044460683264: 'target ceo responds to nationwide boycott of the store over transgender bathroom policy URL URL',
#  693086218276474880: "oh, i'm so ready to watch @zaynmalik's #pillowtalk on mtv tonight at 8:15p. URL URL",
#  692150118921957376: 'jeb bush campaign kicks off 3-state farewell tour with iowa town hall meeting URL URL',
#  656830586577883136: "happy #backtothefuture day! how did 'back to the future: part ii' score on 2015 predictions? URL URL",
#  553543369604210689: 'an 11-month old baby is among the hostages at the kosher supermarket in paris. unbearably sad. URL',
#  767814876433571840: 'rudy giuliani rips @hillaryclinton for dragging colin powell into email scandal: "she lies every day." URL',
#  649985459389661184: 'an openly gay man said that he and his partner met with pope francis a day before kim davis did URL',
#  553531413459660800: 'update - afp says gunman who has taken a hostage at kosher supermarket in paris believed to be suspect in killing of policewoman on thursday',
#  693840291992838147: 'isis claims responsibility for triple bombing that killed at least 45 people and injured more than 100 near damascus. URL',
#  663925546812837888: 'solo cups have been red for decades. if starbucks was taking a shot at christmas, solo shot first.',
#  614604054552018944: 'the @whitehouse is rainbow-colored tonight in celebration of scotus same-sex marriage ruling. URL URL',
#  637382230394822656: 'ben carson: what happened to blacks during slavery is why i am pro-life on abortion today URL URL',
#  661222523275636736: "anonymous to kkk: you can hood, but you can't hide. #opkkk #hoodsoff URL",
#  714531423273746432: 'an open letter to @realdonaldtrump from his top strategist-turned-defector: URL URL',
#  675043569367982081: '‘el chapo’ threatens #isis: ‘my men will destroy you’ - URL URL',
#  544314234541469696: 'uber intros surge pricing in downtown sydney during hostage siege URL URL',
#  651809229842608128: 'avoid 5p bag charge using these from @trolleybagsuk enter here to #win a set with @star100x URL URL',
#  693140340367187969: 'chiefs te travis kelce will have his own reality tv dating show: URL URL',
#  553534838880608256: '#breaking gunman in policewoman killing suspected in new paris hostage-taking: source',
#  633961125126668288: 'a new cnn/orc poll finds @hillaryclinton ahead of @realdonaldtrump by just 6 points URL URL',
#  544512108885725184: 'paramedics are currently carrying out a number of hostages in #martinpl. #sydneysiege #9news',
#  552805488631758849: "at least 12 killed in today's attack on satirical magazine #charliehebdo in paris, official says. URL",
#  645711628046995462: "latest starving 'refugees' from #syria . these guys look like friggin soldiers to me! URL",
#  614608936491188225: 'white house lit in rainbow colors after gay marriage ruling URL URL',
#  693858804279201794: 'poor women in india are fighting for the right to have a job. "when you start working, your heart opens up." URL',
#  674014933235859456: 'dearborn michigan, this morning. pro isis rally. spread the word, the fit is about to hit the shan here in the us. URL',
#  690042063958732800: "#ausopen: british number one andy murray beats australia's sam groth 6-0 6-4 6-1 scores: URL URL",
#  693041285087756288: 'saliha is one of the first women ever to stand for election in saudi arabia: watch her story URL URL',
#  620971220301787136: 'while @cnn is talking about #irandeal nasa confirms earth will experience 15 days of darkness in november 2015 URL',
#  656880145769197568: "10 'back to the future' predictions that came true URL URL",
#  674263945172119552: "1.15 million americans have been killed by guns since john lennon's death URL URL",
#  612646796355960832: 'after arrest, dylann roof was hungry. police bought him food from burger king. more details: URL URL',
#  544511199702822913: 'police move in: police confirm live ammunition used in martin place #sydneysiege',
#  650952376954650629: 'pathetic little twat can’t wait to argue over 5p bag\xa0charge URL URL',
#  693441093048766464: "icymi: joseph pena squatted 875 pounds. he's 17 years old ... URL",
#  553107921081749504: 'two shot in paris, including traffic cop, as manhunt continues for #charliehebdo suspects URL URL',
#  666190716448587776: 'warning syrian refugees hv arrived in neworlean &they r here 2stay ur funds r being well invested in one-way tickets URL',
#  681199637387149313: 'sacha baron cohen and his wife donate $1 million to syrian refugees URL URL',
#  632377165477191680: 'trayvon martin at space camp in florida. #blacklivesmatter URL',
#  652992524504600576: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  763738618573623297: 'hillary clinton strategist bob beckel called for wikileaks editor julian assange to be assassinated: i do not... URL',
#  672927317191229440: 'this is the face of female jihadist #tashfeenmalik could pass for a widow or orphan😤#norefugees #islamistheproblem URL',
#  757367391202471937: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  688819658057740290: 'us trying to locate americans missing in baghdad after al-arabiya reports they may have been kidnapped by militias URL',
#  692845716826300418: 'today, the @deptofdefense took steps to expand paid leave for military moms and dads → URL URL',
#  756282236375277568: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  692748411481780224: 'man held at disneyland paris carrying "low-calibre" guns & copy of koran - police sources URL URL',
#  675193315306905600: 'el chapo vs isis: mexican cartel boss threatens islamic state over drug trade URL URL',
#  674364257799004160: 'adolf hitler vs donald trump URL',
#  716461257025581056: '.@berniesanders is pulling magic tricks out of a hat in nevada. we just officially won! URL',
#  662430295254175744: '#opkkk releases 500+ names and reveals unexpected #plottwist URL URL',
#  544512676643500033: 'breaking @skybusiness: freed hostage borne high from #sydneysiege w/c.4 paramedic teams on the scene URL ( carsonscottli',
#  638050997340893184: 'in celebrity death hoax news, james earl jones is not dead. URL URL',
#  692890520960397312: 'the terps do it again! no. 8 maryland knocks off no. 3 iowa 74-68, has beaten 5 of its last 7 top-5 opponents. URL',
#  544324444773433348: 'uber says it has hiked prices in sydney to "encourage more drivers to come online & pick up passengers." URL #sydneysiege',
#  745236050407194624: "the big one: 'large scale motion' detected along san andreas fault URL URL",
#  673079581520318464: 'do these look like the faces of a homeless couple caught living in a walmart attic for 2 years? URL',
#  691995324752252930: '"the dave i know is polite, modest, and content. jumbotron dave is crass and loud." URL URL',
#  673984270902427650: 'donald trump and adolf hitler. two sides of the same coin. #racism #fascism URL',
#  524975705206304769: "#nhl cancels tonight's game between #ottawa and #toronto due to today's shootings. senators were to host maple leafs.",
#  618805892222468096: 'jay z and beyoncé want to buy rights to the confederate flag: URL URL',
#  693086478667112448: 'the people have spoken: there is now a petition for @snoopdogg to narrate "planet earth" URL URL',
#  614595181845839873: 'the white house is lit up rainbow. URL',
#  654371696195993600: 'colorado mcdonald’s offers first marijuana friendly smoking section in restaurant - URL',
#  665358434351509504: 'breaking: 1st load of 10,000 syrian refugees arrived in new orleans URL #makeamericagreatagain URL',
#  755439197125767169: 'ohio police say an officer was served a sandwich containing glass shards at a restaurant. URL',
#  666633171325353989: 'the myth of zouheir, a "hero muslim security guard" in paris URL (via @bbctrending) URL',
#  729647367457230850: 'leading causes of death in the u.s.: 1. heart disease 2. cancer 3. medical error URL URL',
#  726442550266044416: 'because target believes men can pee with girls, their stock has taken a huge hit. good. keep boycotting target. URL',
#  666070802924617728: 'jindal demands info about refugees entering new orleans... URL',
#  544512664769396736: 'breaking: police enter #lindt cafe, hostages flee URL #sydneysiege URL',
#  692106491365605376: 'apple announces most profitable quarter in u.s. history—and the end of unprecedented growth URL URL',
#  727966590084485120: '.@caitlyn_jenner will reportedly pose nude for sports illustrated URL URL',
#  691789524498845699: 'president obama announces ban on solitary confinement for juveniles in federal prisons - washington post URL',
#  767803368081358848: 'fbi uncovers nearly 15,000 more emails and materials sent to or from hillary clinton. URL URL',
#  667379734343471104: 'donald trump is the new adolf hitler URL',
#  715671763808493569: "☆☆craigslist ad allegedly posted by bernie supporters offered $15 to protest at trump's rally in wisconsin. trump already creating jobs!",
#  653250169752977408: '.@hillaryclinton is ahead of @berniesanders by 19 percentage points, in a new cbs news poll released sunday. URL',
#  656361703664451585: 'well done scotland! 5p carrier bag charge 1 yr old today - 80% cut in usage - 650m less bags -£6.7m for good causes. URL',
#  643103859729166337: 'unreal: watch what happens when desperate muslim refugees are offered red cross food URL URL',
#  714560810266132480: 'letter to trump voters from his top strategist-turned-defector - i don’t know if this is real, but it’s believable. URL',
#  658065957823324160: 'the father of steve jobs, the ground-breaking founder of apple, was a refugee from syria URL URL',
#  693534670428971008: 'up to 100 masked men, dressed in black, involved in "migrant attack" in stockholm URL URL',
#  722885778448121857: "a new transgender bathroom policy at @target is real, and it's fabulous: URL URL",
#  614599619310407680: "white house is aglow in the colors of the rainbow celebrating the supreme court's same-sex marriage decision. URL",
#  706933939953344514: 'bernie sanders speaking about institutional racism 👏🏽🙌🏽 URL',
#  691285663522648065: 'investigations into nearly 60 allegations of unlawful killing against uk soldiers in iraq are dropped, mod says URL',
#  661229627734667264: 'mayors flatly deny klan membership after #anonymous releases names online URL #opkkk #hoodsoff URL',
#  714755546285477888: "donald spunktrumpet's former communications director stephanie cegielski has resigned and written this - URL",
#  672102358516670465: 'holy christ, #samuraijack is returning to television! URL URL',
#  673686233936072704: '72 dhs employees on the terror watch list: URL h/t @penguinsfan62',
#  618192748735299584: 'the kissing islands, greenland! URL',
#  715264793737879553: "donald trump supports abortion ban and 'punishment' for women URL",
#  614594667225571328: 'breaking: the @whitehouse is celebrating with us tonight lit up in rainbow colors. #lovewins URL',
#  693935557009801218: "iran's supreme leader awards medals to troops who 'captured' u.s. sailors URL URL",
#  644229386149888001: 'greek customs captured containers of weapons and ammunition going to refugee camps in europe as "plastic furniture" URL',
#  763428684850094080: 'breaking video : hillary surrogate calls for the assassination of julian assange. URL',
#  671181758692507648: 'desperate ted cruz claims planned parenthood shooter was transgender leftis; based on rumor he read URL',
#  692078399012130816: 'woman a leading authority on what shouldn’t be in poor people’s grocery carts URL URL',
#  752875379765968897: 'ted cruz is apparently riding with the president on air force one en route to dallas. man, barack obama is a saint.',
#  626642648179159040: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  742114513726623744: 'a tweet from @realdonaldtrump about the #orlando shooting: URL URL',
#  716457799392342018: 'bernie sanders has actually won nevada, not hillary clinton! the people have spoken! URL URL',
#  778625026144792577: 'massachusetts court finds that it’s ‘reasonable’ for black men to run from police to avoid racial profiling… URL',
#  614610920782888960: 'there will be cool photos of the white house w rainbow colors tonight but hard to top this one by chuck kennedy. URL',
#  715254040289021952: 'donald trump tells chris matthews: women deserve ‘some form of punishment’ for abortion URL URL',
#  673872171341447169: '72 dhs employees on terrorist watch list URL via @kredo0 URL',
#  693167683701968896: "women in america still earn only $0.79 for every $1 men make. it's time for #equalpay → URL URL",
#  724624672604610562: "people are over here boycotting @target over their new transgender bathroom policy and i'm just like URL",
#  655432919595548672: "thousands of people in china claim they have seen a 'floating city' in the sky URL",
#  692014905239666688: "danish lawmakers approve bill allowing seizure of asylum seekers' valuables to help cover expenses. URL",
#  544520042810200064: '#sydneysiege is over. 2 confirmed dead, #prayforsydney #prayforsydneyhostages #sydney #hostages',
#  692803280238419971: 'usgs: sonic boom confirmed in new jersey area after reports of shaking; cause not immediately known URL',
#  664000310856310784: 'mysterious creature discovered in california, everyone naturally cries alien: URL URL',
#  742571519105077248: "considering the #orlando shooter was a registered democrat i'd like to just put these back here: URL",
#  767541796410839040: "powell breaks silence: clintons trying to 'pin' scandal on me! URL",
#  641972184412327937: 'alert! islam taught in tennessee schools URL #wakeupamerica #tcot #wethepeople #pjnet #ccot URL',
#  651321040119963648: 'el chapo puts $100 million bounty on donald trump...dead or alive! URL',
#  662151653462790144: "hackers from anonymous say they're set to expose hundreds of kkk members URL #opkkk URL",
#  693844030589902848: '.@dylanobrien learned the hard way to not mess with @shelleyhennig: URL URL',
#  676067381299576832: '72 dhs employees on terrorist watch list - washington free beacon URL',
#  544491151118860289: 'sydney hostage-taker - man monis, 49 - originally from iran - self-styled sheikh - accused of sexually assaulting 7 women developing..',
#  544515538383564801: 'haron monis,hostage-taker in #sydney: fled #iran 96,suspect in ex-wife killing,46 sex assaults URL URL',
#  673615400655970304: "shock: 72 'homeland security' employees on terrorist watch list... URL",
#  653432261203750912: 'why drunk vegetarians eat meat URL via @thedailybeast',
#  641443248909754368: "kim davis angers 'eye of the tiger' creator after using song at prison release URL",
#  614601139422633984: 'white house lit in rainbow colors following us supreme court ruling that same-sex couples have right to marry. URL',
#  524931324763992064: 'very reliable source on parliament hill tells me the assailant has been killed. #cdnpoli #ottnews',
#  707786906189303808: "meet kenny the tiger. he was born with down syndrome. he's proof you don't have to be perfect to be beautiful ❤️ URL",
#  656047932093763584: 'cnn/orc poll: clinton did best in 1st dem debate, but only sanders significantly increased support in past month. URL',
#  723025600810766336: '#ripchyna: the wwe icon has passed away at the age of 45. URL URL',
#  656595123590012928: "10 'back to the future' predictions that actually came true URL URL",
#  615346611955183616: 'breaking: south carolina to ban sale of tylenol. they fear picking of cotton from the bottles may represent slavery. URL',
#  763524712853102596: 'hillary clinton strategist bob beckel called for wikileaks editor julian assange to be assassinated. #dncleaks URL',
#  663817239896821760: 'for everyone who thinks starbucks red cups are ruining christmas URL URL',
#  659462980476637184: 'fda confiscates several thousand chickens from kfc farms as mutations worsen URL URL',
#  669259395902152704: 'months ago, rupert murdoch bought national geographic and fired most of writers. this just hit the stands. URL',
#  620367840902782976: "translucent butterfly - beautiful! ' URL",
#  733242244522725376: '🎯 #target backlash over transgender bathroom policy hits "boiling♨️point"❗️ URL #boycotttarget URL',
#  544301453717041152: 'breaking update: gunman says four devices are located around sydney. security response underway. police calling for calm. 9news',
#  628045645010608128: 'sylvester stallone was so broke before his script for rocky was accepted that he sold his dog for $25. after he bought it back for $15,000.',
#  672169954016403456: 'pres. obama on #sanbernardino: "we have a pattern now of mass shootings in this country that has no parallel." URL',
#  693076140278153217: 'michael phelps\' gold medals and speedo crashed asu\'s "curtain of distraction" last night. you read that right. URL',
#  674314254732931072: '.@presssec: @realdonaldtrump comment "disqualifies" him from presidency URL via @talkopan URL',
#  714555825122107392: 'an open letter to trump voters from his top strategist-turned-defector URL @juddapatow @andylassner @bettemidler',
#  611039775856812032: "what's lurking underneath that crispy crust? a kfc customer claims he got a fried rat: URL URL",
#  778681502825451520: 'black men have legitimate reason to run from police – #massachusetts supreme court URL URL',
#  525068915068923904: '***exclusive*** michael zahaf-bibeau caught on a #dashcam model sold at URL #ottawashooting URL',
#  740791134146965504: "dear @hillaryclinton you're not the 1st woman presidential candidate. victoria woodhull is. look @realdonaldtrump URL",
#  544504183341064192: 'escaped #sydneysiege hostage, elly chen, a top student and skilled sportswoman URL URL',
#  553476490315431937: 'police convoy and helicopters are rushing to scene to detain charlie hebdo massacre suspects URL URL',
#  761573188543229952: 'good news: our businesses have added 15 million jobs over the past 77 months → URL URL',
#  673696115305406466: '72 dhs employees on terrorist watch list URL',
#  651825062174195712: 'ben carson is the most brainless brain surgeon in america. my new column: URL',
#  633949800761700352: 'cnn/orc poll: donald trump now competitive in general election URL via @jennagiesta URL',
#  761999790892806144: '“our team boasts the most women who have ever competed for any nation at any olympic games.” —@potus on @teamusa: URL',
#  553587013409325058: "#breaking charlie hebdo gunmen's hostage freed and safe after police assault",
#  544513524438155264: 'sydney siege: police enter cafe as hostages flee the scene, gunfire heard, reports of an injured person – live URL',
#  672539897899577344: 'mass shootings list. reagan - 11 bush sr - 12 clinton - 23 bush jr - 16 obama - 162 #sanbernadino',
#  693691456222052352: 'red alert! drake just dropped a new single called, "summer sixteen" from his new album. URL URL',
#  693648684857323521: 'spoiler alert: leo and kate were ridiculously cute together at the 2016 #sagawards. URL URL',
#  655812191233417216: 'when refusing to pay the 5p bag charge backfires URL 😂🙈',
#  672219174463275008: 'pres. obama on #sanbernardino: "we have a pattern now of mass shootings in this country." URL URL',
#  614628865353351168: 'the white house takes on rainbow hues in celebrating #scotusmarriage decision: URL URL',
#  727854332188577792: 'perhaps media should ask hillary about this clinton campaign made payments to hard drive destruction company URL',
#  544358564484378624: 'police: negotiators are now in contact with armed hostage-taker in sydney situation; motive remains unknown - URL',
#  742012307694223361: '#orlando oh look the muslim shooter was also a democrat! URL',
#  707332312724283392: "obama to skip nancy reagan's funeral for music, film festival in austin, tx URL via @waynedupreeshow",
#  755447443009916929: 'police shut down restaurant after officer cuts mouth on shards of glass found in sandwich URL URL',
#  693555965019492352: 'denver medical center on lockdown; 9 at hospitals after deadly incident at denver coliseum URL URL',
#  705092738224525312: 'breaking news: search "how can i move to canada" skyrocketed following #supertuesday URL',
#  724661834419048448: "hey guys, target isn't backing down check the usa today article about the boycott URL",
#  757190314880884736: 'donald trump: "...laziness is a trait in blacks. it really is, i believe that. it’s not anything they can control.” URL',
#  544278985249550337: 'geoblock lifted on #abcnews24. streaming coverage of the martin place siege in sydney here URL',
#  544367462012432384: 'more: police confirm 3 hostages escape sydney cafe, unknown number remain inside URL #sydneysiege',
#  775672628493357057: 'clinton hides failing health? full disclosure now: covert doctors and nurses URL via @mailonline #maga @realdonaldtrump',
#  692797856386777089: 'an adorable young fan asked riley curry to be his valentine ... and steph responded: URL URL',
#  614645853291155457: 'as sun goes down, white house lights up rainbow colors to celebrate scotus ruling: URL URL',
#  682916727282270208: "erdoğan cites hitler's germany as example of effective government URL",
#  725983128444129280: 'starve the beasts destroying our #civilsociety #target stock ➡️ sinks $1.5 billion URL URL',
#  766808183696351233: '"laziness is a trait in blacks"-trump, according to former president of trump plaza hotel and casino @vitico46 URL',
#  552791196247269378: "breaking: at least 10 killed in shooting at french satirical newspaper charlie hebdo, paris prosecutor's office says. URL",
#  524943490887991296: 'confirmed | 1 shooter shot dead at parliament hill, but there is more than 1 suspect. #cbcott #ottnews',
#  667534186450825216: "steve jobs' biological father was a syrian immigrant.",
#  687643002240679936: 'three men found guilty of involvement in "largest burglary in english legal history" at hatton garden URL',
#  723511860516016128: 'all in purple: memorials and landmarks across the globe honor #prince after his death. URL URL',
#  677099574855639044: 'plumber suing car dealership for $1m after truck he traded in ends up in hands of isis: URL URL',
#  544391533240516608: 'five hostages have escaped the besieged lindt cafe in #sydney | our latest update: URL URL',
#  656825206045020160: "#backtothefuture fans, it's october 21, 2015 — the future is finally here! URL URL",
#  525025279803424768: "the soldier shot dead in wednesday's ottawa attacks has been named as cpl. nathan cirillo of #hamont #ottawashooting URL",
#  693119705469587456: 'nasa astronaut @stationcdrkelly captures a beautiful sunrise from aboard the international space station. URL',
#  666051332504207360: 'jindal protests sending of syrian refugees to new orleans URL URL',
#  692929779696275456: 'ohio lawmakers want to know why state’s epa didn’t tell public about lead leaking into water supply of sebring. URL',
#  650975967146602496: "uk • you're right to be nervous about the 5p plastic bag charge. when they implemented this in california the streets ran red with blood.",
#  553544694765215745: "french police publishes photos of suspect in yesterday's montrouge shooting. maybe the same persons in kosher market URL",
#  674080899055546368: 'a vote for donald trump is a vote for adolf hitler.',
#  626770498328895488: "translucent butterfly - beautiful! ' URL",
#  657007736467525632: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  614626710248534016: '"these colors celebrate a new chapter in the history of american civil rights." #lovewins URL URL',
#  751536167183613952: "#urgent so-called 'purge' planned tonight in baton rouge 1200am - 0500am. #bluelivesmatter - heres the flash >> URL",
#  693771953648373760: 'in china, 77% of jobs are threatened by automation URL URL',
#  649903655160815616: "vatican says #kimdavis' meeting w/ #popefrancis 'should not be considered a form of support.' URL URL",
#  692082861525078017: 'tony the tiger has no more cummies left to give URL URL',
#  614054616154550273: 'charleston church shooter dylann roof receives $4 million in donations from supporters - URL URL',
#  674301960787505153: 'donald trump has been disqualified for running for president URL',
#  658755852199927808: 'test finds human dna in hot dogs, meat in vegetarian products URL URL',
#  748543642323783681: 'obama cuts military pay third year in a row, while pushing $15 min. wage for burger flippers URL URL',
#  614494170590367744: "theres' a double rainbow over the white house URL",
#  661870323034431489: 'holy shit. rupert murdoch just killed national geographic. URL',
#  637873886072320001: 'sanders closes to 7 points behind clinton in new iowa poll. URL URL',
#  732004388181434368: 'target’s new transgender policy raises all sorts of questions. URL',
#  689938201193115648: '.@potus on declaring a federal emergency in #flint, michigan to supplement state and local response efforts. URL',
#  645362146415525888: '#bulgaria finds 10,000 #fake passports hidden by #muslim refugees heading for #germany passports for #terrorists URL',
#  692758581494599681: 'french police hunting woman who was with an armed man arrested near disneyland paris. URL',
#  672632863452299264: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  727187859367546880: 'good news!: target stock plummets #lbgtq #bathroombill URL #tcot #pjnet #rednationrising URL',
#  764931593303646208: "fox news host claims hillary clinton had seizure on camera, has 'secret' health issues URL URL",
#  525056576038518785: 'soldier killed in canada shooting was a young reservist with a six-year-old son URL URL',
#  672433211604013057: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  747275598347837440: 'newsflash⚡️the #orlando shooter was a muslim and a democrat✔️ not a republican or christian❌ #gaypride2016 URL',
#  774833492865593344: 'nurses save lives of all different races and colors, but @hillaryclinton thinks we belong in a #basketofdeplorables. URL',
#  760928376668454912: 'before hillary clinton, there was victoria woodhull, a pro-life feminist who ran and was nominated for president. URL',
#  728013148788154368: 'report: caitlyn jenner will pose nude for sports illustrated URL URL',
#  614618682543616000: 'white house shines rainbow-colored lights in honor of #scotus gay marriage decision #lovewins URL URL',
#  693060960001597440: 'mark zuckerberg is now richer than the koch brothers 💰 URL URL',
#  693826104633737217: 'watch bernie sanders sing "this land is your land" with vampire weekend at iowa students rally URL',
#  723644048867774464: 'niagara falls turned purple on the day prince died: URL URL',
#  742050150307246080: 'shooter in orlando was: a. muslim b. registered democrat voter c. isis d. homophobic e. ready for hillary URL',
#  675064077367005184: 'el chapo threatens isis URL URL',
#  524926235030589440: 'breaking news: at least 3 shots fired at ottawa war memorial. one soldier confirmed shot - URL URL',
#  749286768554438658: "what's the no. 1 killer of americans? these rankings have changed little over the years URL URL",
#  544380742076088320: 'this is shot that captures the #sydneysiege: sheer terror/relief of escaped hostages, incredible work of @nswpolice URL',
#  614605997953404929: "white house lit in rainbow colors after high court's gay marriage ruling (with photo) URL",
#  629503919098429440: 'chick-fil-a to open on sundays URL',
#  692623941131722752: '3-legged dog expected to survive after getting shot while scaring off armed robbers. URL URL',
#  626546123713474560: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  672906198434209792: "farook family attorney says brothers in the family never saw tashfeen malik's face because she always wore a burka. URL",
#  673615263040798726: '72 dhs employees on terrorist watch list URL',
#  647169573599449088: "new cnn democratic poll: bernie sanders 46 hillary clinton 30 joe biden 14 martin o'malley 2",
#  641050980985999360: 'happy "$15 minimum wage" labor day from mcdonalds URL',
#  727179214546456577: "target's stock has taken a $2.5 billion hit over its insistence on insulting regular customers URL",
#  666107476526432256: 'muslim security guard stopped bomber from entering the stadium during #parisattacks URL #zouheir URL',
#  620916279608651776: 'nasa confirms earth will experience 15 days of complete darkness in november 2015 - URL URL',
#  673664899571060736: '72 dhs employees on terrorist watch list URL via @kredo0 URL',
#  544271284796784640: "developing: gunman takes hostages in sydney cafe, 'isis' flags being held against window - URL URL",
#  692071267189395457: "here's why @potus is taking steps to ban solitary confinement for low-level infractions: URL URL",
#  651486105628463105: 'black people can be so stubborn to change.... #5pbagcharge URL',
#  675065047710892033: 'mexican drug kingpin \'el chapo\' reportedly threatens to destroy isis "p*ssies." URL URL',
#  668144671772778497: 'according to anonymous, the next isis target is a wwe event in atlanta. URL URL',
#  604625816992002049: 'the kissing islands, greenland. URL',
#  682996350909157376: "turkey's president says all he wants is same powers as hitler URL URL",
#  688752927381581824: '"today’s progress...these things are a reminder of what we can achieve when we lead with strength and wisdom." —@potus on progress with iran',
#  693087220459270144: "4 miners now rescued from mine in china's shandong after 36 days underground - state media URL URL",
#  524962142563610625: '#breaking rick hughes at cbc hamilton: the soldier who was shot in ottawa wednesday morning is a reservist serving in hamilton',
#  693573781730783232: "ooh, baby! dickie v loved this reverse dunk by ben simmons. lsu's up double-digits on no. 1 oklahoma: URL",
#  692083780123783172: 'actor abe vigoda has died at 94 URL URL',
#  627828211003469825: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  693059995013742592: 'mook spooked: hillary manager predicts trump will win presidency if nominated!',
#  614594195479752704: "white house lit in rainbow colors after today's historic supreme court ruling #scotusmarriage URL",
#  692691444046372865: 'zika virus "spreading explosively" around the americas, who director-general says. URL',
#  614593989203886080: 'the @whitehouse is lit up like a rainbow! #lovewins URL',
#  690376107825192960: 'happy #nationalhugday! URL',
#  658259426172891136: '4 legged chickens: fda confiscates several thousand chickens from kfc farms as mutations worsen URL',
#  676586804242309121: 'isis has been killing babies afflicted with down syndrome and other disabilities, activists claim URL',
#  651959206287908868: "donald trump's capture, dead or alive, is reportedly worth $100 million to el chapo. URL URL",
#  681147789653356544: 'katy perry -- makes holiday wish come true for burn victim URL',
#  652882609219833856: ".@realdonaldtrump: what's the secret of my popularity? my looks. i'm very handsome. URL URL",
#  544476808566276097: "tv channels have chosen not to show videos of hostages relaying #sydneysiege gunman's demands. URL URL",
#  687274510643511296: 'the oregon militia idiots would like you to stop mailing them dildos, please URL URL',
#  647464349611589632: 'poll: @hillaryclinton trails @berniesanders in new hampshire, even without @vp in the race URL URL',
#  726086935903494144: 'target boycott crosses 1 million signers, stock sinks by $1.5 billion - breitbart URL',
#  691632238035886081: 'former conservative minister lord cecil parkinson dies aged 84, after suffering from cancer, his family says URL',
#  524952883343925249: "watch video showing gunfire inside canada's parliament in ottawa URL URL",
#  688021039322894336: 'kosovo war crimes court to be set up in the hague, dutch government says URL',
#  707308274270539777: "no one is surprised by this.of course obama is skipping nancy reagan's funeral.dignity isn't his strongest attribute URL",
#  691678576018657281: 'adorable but frightened sloth rescued from side of highway in ecuador URL URL',
#  692874200927698945: 'report: las vegas sands to propose $1 billion domed stadium to possibly draw nfl franchise - fox5 las vegas URL',
#  666640008149925893: 'son of a syrian refugee URL URL',
#  663515735231062016: 'michelle obama says ‘white folks’ are what’s wrong with america URL no michelle you are whats wrong with america',
#  643139873264812032: 'and so it begins…isis flag among refugees in germany fighting the police [pictures] URL URL',
#  689860942671130624: "7 years ago, @potus bet big on rescuing the american auto industry. here's how it paid off: URL URL",
#  656662726014599168: 'the father of steve jobs, the ground-breaking founder of apple, was a refugee from syria URL URL',
#  674229534888185856: 'who said it: donald trump or adolf hitler? URL URL',
#  716424773216022530: "it seems @berniesanders has won back nevada! don't let @clarkcountynv dems rig it against @sensanders! #feelthebern URL",
#  672432930426372096: 'ever wonder why the most mass shootings ever have happened under obama? URL via @rebootliberty URL',
#  600451916414484480: 'nasa recently released imagery showing the deforestation of america …in just 34 years. URL',
#  692838430783332357: "nation's dog owners demand to know who's a good boy URL URL",
#  717081129627553792: "this is kenny, the tiger with down syndrome. this proves you don't have to perfect to be beautiful ❤️ URL",
#  765612862681255936: '.@greysabc season 13 will focus on the "originals" URL #greysanatomy URL',
#  641088973717110784: '#imachristianbut i wish chick-fil-a was open on sundays.',
#  652349108653551616: 'surprising number of vegetarians secretly eat meat URL URL',
#  777710439870455808: 'all living ex-presidents warn against donald trump URL URL',
#  553508098825261056: 'police have surrounded this building where the suspected #charliehebdo attackers are holed-up URL URL',
#  762793077509464064: '"if you could compete in any olympic event, what would you choose?" —@potus asks @flotus: URL URL',
#  614628136634949632: 'the @whitehouse is lit up in a rainbow #lovewins URL',
#  580324027715063808: 'just in: germanwings plane crashes in southern france, up to 150 feared dead URL',
#  634665777400950784: 'translucent butterfly URL',
#  674301413040758785: '.@presssec: @realdonaldtrump muslim comment "disqualifies" him from presidency URL URL',
#  613362193787129860: 'the kissing islands, greenland. URL',
#  743764020679741440: 'obama cuts military pay for third year in a row, while pushing for $15 min. wage for burger flippers: URL',
#  692820029159653377: 'beck on david bowie: "he’s always been a guidepost for me" URL URL',
#  693471161313816576: 'lego’s first-ever figurine in a wheelchair is prompting ‘genuine tears of joy’ URL',
#  716092408920936448: 'international criminal george soros & his boi @davidbrockdc are sooo busted #fauxprotests #ringers @realdonaldtrump URL',
#  524941132237910016: "here's that dramatic video via @josh_wingrove of shots fired inside parliament building: URL #ottawa #shooting",
#  727116900983934976: '. @target stock plunges in early days of @americanfamassc boycott. URL',
#  655986243042459648: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  544283772569788416: 'live updates: siege in sydney cafe URL',
#  693818562981421056: "icymi: somehow lebron came out in shorts that didn't match the rest of his team ... so he had to change mid-quarter. URL",
#  658938136299511808: 'human dna found in hot dogs - and 10% of vegetarian sausages contain meat URL URL',
#  618449248179191808: 'girl killed in her sleep from wearing earbuds while iphone was charging - URL URL',
#  693897857376632832: 'clinton ominously tells iowan supporters to mark front doors with campaign logo before sundown URL',
#  692410832307818497: 'will you watch thursday’s #gopdebate if @realdonaldtrump is not on stage? URL',
#  662381914842603520: 'rt @operation_kkk: official #opkkk #hoodsoff 2015 data release URL with love, anonymous . URL',
#  615494435074363392: 'if they can light up the white house like a rainbow for gay pride, it sure as hell better be red, white & blue for independence day. merica.',
#  763520953619918848: 'dear #msm bob beckel calling for assassination of #julianassange URL @ericbolling URL',
#  766568413418356736: 'us swimmer jimmy feigen to pay $11,000 to charity as part of deal to settle brazil robbery dispute - us media URL',
#  676367888543031296: 'north carolina town rejects solar panels for sucking "up all the energy from the sun.” URL URL',
#  692758050378256388: 'elvis presley made his tv debut 60 years ago today. look back at his history on the tube URL URL',
#  642465192408940544: '#wakeupamerica heads need to roll! school forcing non-muslims to praise islam URL #bansharia URL',
#  612438528803213312: 'after police arrested #dylannroof, they went and bought him burger king because he was hungry. #charlestonshooting URL',
#  613425834301485056: 'police bought #dylannroof food from @burgerking after he was arrested for church shooting: URL URL',
#  714567472712589312: 'how many more trump supporters will defect? an open letter to trump voters from his top strategist-turned-defector URL',
#  693281966846808064: 'a head-on collision with another planet may have created our moon, researchers say URL URL',
#  659428447459110912: '#opkkk: #anonymous to reveal identities of 1,000 ku klux klan members URL URL',
#  672902686380003328: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  659439879701602304: 'fda confiscates several thousand chickens from kfc farms as mutations worsen URL URL',
#  553590459688570880: 'several hostages freed at jewish supermarket in paris. photo thomas samson #afp URL',
#  525058976376193024: 'our thoughts and prayers go out to nathan cirillo who died today in ottawa while protecting his country at age 24 URL',
#  669201837187334144: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  652300118205427716: 'survey: 1 in 3 vegetarians admits to eating meat when drunk... URL',
#  693203974388895744: 'a tiny alpine town in northern italy just welcomed its first baby in 28 years 🍼👶 URL URL',
#  747443219487678464: 'nyc pride parade after orlando: “republican hate kills" no. the orlando shooter was a muslim democrat. URL',
#  755548076438196225: 'colombus, ohio police officer served sandwich with shards of glass. URL',
#  728627623488786433: 'breaking: tom brady set to share sports illustrated cover with caitlyn jenner.... URL',
#  553476880339599360: 'developing: police pursuing #charliehebdo shooting suspects, helicopters deployed - live feed: URL URL',
#  749039299677417472: 'after the orlando shooting this is how they protest, and the shooter was a registered democrat... URL',
#  687537772970684417: 'jakarta attacks: #kamitidaktakut hashtag shows indonesians are not afraid URL',
#  725070832494624769: "boycott the hell out of target. they think it's ok that boys pee with girls so let's hit em where it hurts - money. URL",
#  728038172270198787: 'caitlyn jenner will pose nude on the sports illustrated cover. nothing says sexy like a 66 year old chick with balls.',
#  500378223977721856: 'oh. so now the #ferguson police chief says the cop didn\'t know about the robbery when he stopped #mikebrown. the kid was "jaywalking"? bs!',
#  724348906096590849: '340,000 pledge to boycott @target over transgender bathroom policy URL URL',
#  658786161733734400: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  728207861050970112: 'caitlyn jenner will pose nude on the sports illustrated cover. her balls will be censored by a sad michael jordan face.',
#  651402689352351744: 'help the red cross provide food, water & cots for refugees across europe. URL \xa0 #aidrefugees URL',
#  634943791934406657: 'marilyn monroe and james dean smoking in new york city URL',
#  544319832486064128: 'hostage situation erupts in sydney cafe, australian prime minister says it may be "politically motivated" URL',
#  693606934050684928: 'looking at eddie redmayne looking at alicia vikander is making us all kinds of emotional. #sagawards URL',
#  666810213274689537: 'but democrats say that syrian refugees are 3 year-old orphans. so why are they worried about them buying guns?',
#  692702295281262593: 'the @who predicts 3 to 4 million cases of #zikavirus that is spreading through americas URL',
#  692498490249891842: '"an attack on any faith is an attack on all our faiths." —@potus at @israelinusa',
#  689867195657101312: '13 questions with @madisonbeer, the 16-year-old singer @justinbieber discovered on youtube: URL URL',
#  553512735192141826: 'update - afp: an unnamed police source says the killing of the policewoman in #paris on thursday is linked to the #charliehebdo attack',
#  544517264054423552: '#breaking: police have confirmed that the #sydneysiege is over. #9news',
#  656629493377990656: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  663744139666804736: "as you ignore the cold homeless guy sitting outside starbucks, please be sure to complain about the 'non-christian' red cup of $5 coffee.",
#  675005503160901632: 'after mass shootings, obama seeks to expand background checks for gun sales by executive order to bypass congress URL',
#  638047610973089793: 'obese woman arrested for starving her 7 kids: "there was only enough food for me" URL URL',
#  727623131494387714: 'clinton campaign made payments to hard drive destruction company 🤔 destruction of 14 hard drives @hillaryclinton ⁉️ URL',
#  723198441690636288: 'pop legend prince has died at 57: URL URL',
#  641082932740947972: 'judy carne, ‘sock it to me girl’ on ‘laugh-in,’ dies at 76 URL',
#  648894687542034432: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  692925396292091905: "paul kantner was jefferson airplane's conceptual heart. here are 12 essential songs URL URL",
#  752965545528528898: 'homicide is among the top five causes of death in adolescents URL #endviolence URL',
#  778572032531427332: 'massachusetts court finds that it’s ‘reasonable’ for black men to run from police to avoid racial profiling… URL',
#  716451800581279744: "it's official, @berniesanders actually won nevada today. came down to 2 factors. 1. enthusiasm 2. organization URL",
#  637868242560638980: 'woman stabs boyfriend for not liking instagram selfie fast\xa0enough URL URL',
#  498430783699554305: 'witness: police allegedly stopped mike brown after yelling at him to walk on sidewalk. #ferguson URL',
#  641430951403343872: 'translucent butterfly - beautiful! URL',
#  635632641635667968: "'great pacific garbage patch' researchers return with data URL URL",
#  652000523525091328: "a third of 'vegetarians' eat meat when drunk on a night out URL URL",
#  626897206717624320: "did a real life 'fallen angel' just fall from the sky in london? ‼️‼️ 👉 URL 👈 URL",
#  693476774462820352: 'merkel says refugees must return home once war is over URL',
#  626516248206135296: 'this is how people in china are riding escalators after a horrific accident URL URL',
# ...
#  544268732046913536: "#breaking: hostages are being held and a siege is taking place at sydney's lindt chocolat cafe in martin place.",
#  767855091109863424: '.@stephenfhayes: "this is about hrc having made repeated representations that have turned out to be false." URL',
#  692911086920667136: "in asu's curtain of distraction, michael phelps brought out his gold medals and speedo to do the trick. it worked. URL",
#  544282005941530624: 'hostages in sydney cafe made to hold up islamic flags URL',
#  614609560658161664: 'the white house is lit like a rainbow tonight in honor of the #scotusmarriage ruling. URL',
#  580348081100734464: '#germanwings "sorry to confirm" 144 passengers & 6 crew on board flight #4u9525 when it crashed in french alps URL',
#  723504069814444033: 'purple reign! landmarks light up for prince after his sudden death 💜 #princerip URL',
#  553586860334010368: '#charliehebdo killers shot dead by police',
#  640118021101604864: 'the insane reason why chinese drivers intentionally kill pedestrians they hit — via @slate URL URL',
#  688751061503442944: '"we have now cut off every single path that iran could have used to build a bomb." —@potus #irandeal URL',
#  778530869208190976: 'hillary overcharges poorest campaign donors @lindasuhler @realdrgina @girlsfortrump @cinderella2b @kamvtv #us #usa🇺🇸 URL',
#  544291804057960448: 'first photos: hostage pressed against a window. #sydneysiege URL',
#  688004802245214208: "study: minimum wage increases haven't hurt the restaurant industry. URL",
#  743126914794037248: "people blame the massacre in orlando on the nra. newsflash: the orlando shooter wasn't a nra member... but he was a registered democrat.",
#  653432177632387072: 'study finds over a third of vegetarians eat meat...when drunk! URL URL',
#  628604055644934144: "whole foods' selling asparagus water is a sign the end times are near URL URL",
#  692163879909064704: "#teenwolf starts in 5 minutes! rt if you're watching + tweeting + crying + screaming with @mtvteenwolf & me! URL",
#  728273551883534336: 'caitlyn jenner will pose nude on the sports illustrated cover. her balls will be censored by a sad michael jordan face.',
#  524942470472548352: 'the university of ottawa, just a five minute walk from the hill, is now on lockdown.',
#  552792544132997121: 'breaking charlie hebdo latest: 11 dead 10 wounded (five critical) two gunmen unaccounted for URL URL',
#  727834854931435522: 'evidence destroyed? campaign made payments to hard drive and document destruction company URL #makeamericagreatagain',
#  544289311504355328: 'statement from prime minister tony abbott on sydney hostage situation. URL',
#  614494460747997184: "theres' a double rainbow over the white house URL",
#  615592870540488704: 'if they can light up the white house like a rainbow, it sure as hell better be red, white & blue for independence day.',
#  689661418484994049: '.@arianagrande just created a unisex fragrance named after her brother: URL URL',
#  724603564946010112: 'twenty-five stories proving target’s pro-trans bathroom policy is dangerous URL',
#  714598318333042688: 'top trump strategist resigns, writes revealing open letter: URL',
#  656848877463560192: 'i’m celebrating #backtothefuture day by bemoaning the lack of hoverboards while ignoring the fact that my phone contains all human knowledge',
#  692157602554343424: 'waiting for the new episode of #teenwolf like... URL',
#  765735409984806912: 'trump: dems "failed and betrayed the africanamerican community” trump: “laziness is a trait in blacks, it really is" URL',
#  614610102927147008: "bro there's either a black president in a rainbow whitehouse or i'm having the best trip ever",
#  614650850393391104: 'wow! what a way to end this historic day! URL #lovewins #loveislove #equalityforall #lgbt URL',
#  614648099542204416: 'white house shines rainbow-colored lights in honor of #scotus gay marriage decision #lovewins URL URL',
#  544514564407427072: 'police seem relaxed, suggesting all hostages are out and gunman no longer a threat URL #sydneysiege',
#  707305999971921920: '‘president petty strikes again’: obama will reportedly skip nancy reagan’s funeral,,, ✅ URL URL',
#  644329878876237824: 'alert: tsunami advisory issued for southern california from 3-7 a.m. local time. stay away from ocean and shoreline. #cawx #tsunami',
#  553566026030272512: 'breaking: two hostage situations in france are linked, paris prosecutor says',
#  715253497462145024: 'just in: donald trump to @msnbc: "there has to be some form of punishment" for women who have an abortion.',
#  693804277031157761: 'unstoppable! novak djokovic is now a perfect 6-for-6 in australian open finals after his win over andy murray. URL',
#  715268937873760256: 'donald trump goes full anti-woman: "punishment" for women who abort URL URL',
#  763964234774347776: '.@theweeknd donates $250,000 to black lives matter URL via @cnnent URL',
#  614616994499788800: "there's a rainbow over the white house right now, just the same as when dublin had one the day ireland legalized URL",
#  693185853867294721: 'meet quasimodo, the dog with the short spine URL URL',
#  553506608203169792: 'map shows industrial estate where 2 #charliehebdo suspects are holed up, surrounded by police URL URL',
#  751856580874960897: 'should say "labor unions aligned with @hillaryclinton" stopped dems from saying no tpp-they don\'t speak for nurses URL',
#  712223438698627073: "keith richards 'once pulled a knife on donald trump', claims rolling stones' former promoter URL URL",
#  707405809181917184: 'bachmann: obama "classless" for missing nancy reagan’s funeral URL URL',
#  693013768738115584: "uk heterosexual couple who want to enter civil partnership rather than marry lose challenge at london's high court URL",
#  744390771869102080: 'one of the men who wanted to copy the #orlando shooter was stopped in l.a. he was a liberal democrat and #berniebro. URL',
#  524959809402331137: 'senior u.s. official: canadian government has informed u.s. that one shooter is dead in ottawa. live blog: URL',
#  778689027918618625: 'black men may have cause to run from police, massachusetts high court says URL',
#  707412869860696064: 'bachmann slams "classless" obama for skipping nancy reagan’s funeral URL URL',
#  650710483289419776: 'local school art project titled "candlelight" URL',
#  656523458139045889: 'is your drug dealer charging you more because of the 5p bag charge? let us know! ring 101 now URL',
#  693135382309896192: 'breaking: canada has four recent cases of #zika, all from travelers: public health agency',
#  623533663947517952: 'gay marriage ruling? white house in rainbow colors within hours. 4 murdered marines & a murdered sailor? 5 days to lower the flag. nice.',
#  692833140428017664: '"let\'s not make the next two weeks about a \'black qb.\' let\'s just talk about the greatness of this guy." -c. barkley URL',
#  614599815280857088: 'look: @whitehouse lights up in rainbow colors to celebrate #scotus same-sex marriage ruling URL',
#  693853310479155200: 'meet our new fave celebrity couple: leonardo dicaprio and his vape pen URL URL',
#  614615157730357248: 'watch live: as sun goes down, white house lights up rainbow colors to celebrate scotus ruling URL URL',
#  714851393861881857: "trump's top strategist, stephanie cegielski, has quit his campaign + just wrote an open letter to trump supporters: URL",
#  767859423150759936: 'study links clinical depression to getting dunked on URL URL',
#  764906140257837056: '"my dad is in the air force and that inspired me to have my back up job be president" —lily: URL URL',
#  619242759359037440: 'obama 2008:"i support traditional marriage, christians vote for me" obama 2015:"the white house is a rainbow. bring me my unicorn" merica.',
#  552792913910833152: 'at least 11 dead in shooting at hq of #charliehebdo in #paris (police source) URL',
#  764368020391223296: 'video : clueless hillary clinton calls for americans to respect and empathize with isis URL',
#  741995157969592321: 'orlando shooter, muslim, omar mateen was a registered democrat. URL',
#  767754921403899906: 'of the 54 killed by young suicide bomber at wedding in turkey, 22 were under the age of 14. URL URL',
#  692940257134653441: 'icymi: a dog accidentally stumbled into the middle of a local half marathon ... and earned 7th place. URL',
#  667487418388488192: 'the picture of a syrian child "surrendering" to a camera is real. URL URL',
#  553586897168392192: '#breaking : both charlie hebdo suspects killed as police storm building (police sources) URL URL',
#  730516765525082112: "a canadian teen didn't find a lost mayan city: URL URL",
#  693128224960856064: 'iranian surveillance drone flies over u.s. aircraft carrier in persian gulf URL URL',
#  553221600955621376: "clarissa, 27 years old, police trainee of montrouge police in #france. victim of this morning's attack. via @_batou_ URL",
#  693071538896162816: 'orphanage saved by bikini car wash URL URL',
#  693869818366287872: 'vanessa hudgens\' father, gregory hudgens, dies the night before "grease: live" URL URL',
#  714998347111669760: 'we must address the political marginalization and institutional racism affecting people of color. read my plan: URL',
#  686666933949837312: 'the guardian front page, tuesday 12 january 2016: david bowie 1947-2016 URL',
#  767710042816602112: "powell: don't 'pin' this on me: ex-secretary of state rejects clinton claim he 'told her to use' email server URL",
#  714811995573325828: "an open letter to trump voters from his top strategist: stop supporting him, he doesn't want to win URL",
#  728101712762834944: 'caitlyn jenner about to post nude for cover of sports illustrated.... 😳',
#  544399927045283840: 'nsw police confirm 5 hostages have emerged from #sydneysiege and they are negotiating: "it might take a bit of time" URL',
#  524947674164760577: 'breaking news: new york times is reporting the canadian soldier who was shot has died from their injuries. heartbreaking. #cdnpoli #ableg',
#  701539698452393986: 'the 2016 race: no, the polling doesn’t prove bernie sanders won the hispanic vote in nevada URL',
#  653285570383335424: '5p!!! hell no!!!!!! #5pbagcharge 😵😵 URL',
#  552792802309181440: '#charliehebdo - 11 dead including 2 police in paris shooting. photo @martinbureau1 #afp URL',
#  707310135291416576: "obama to skip nancy reagan's funeral, as he did scalia's. this time, he'll be attending sxsw: URL",
#  693196937172951040: '"i almost started crying ... but i didn\'t want them to make me the crying face instead of jordan." --draymond green URL',
#  614891047886434304: 'the white house was lit up with rainbow lights to celebrate marriage equality: URL URL',
#  525023025792835585: '#ripnathancirillo rt @globeandmail: soldier killed at war memorial identified as cpl. nathan cirillo #ottawashooting URL',
#  765887221736046592: '#whiteliberalproverbs" i\'ll have them n*ggers voting democratic for the next two hundred years". lbj, founder of the modern welfare state',
#  767561970182598657: 'nothing to see here. just nuggets forward wilson chandler catching a 350-pound fish: URL URL',
#  687984820815851521: "jimmy fallon and sesame street characters photobomb families & it's seriously adorable: URL URL",
#  544282227035869184: 'breaking news: gunmen take hostages at sydney cafe, wave islamic flag URL URL',
#  766822417712963584: 'it\'s been 5 years since "what makes you beautiful" lit up our world like nobody else: URL URL',
#  553558982476828674: 'on israeli tv, an israeli woman speaks of her nephew,a mother with 6 month old baby, held hostage in the supermarket in paris. #jesuisjuif',
#  544290258951892992: 'central sydney shut down by police amid ongoing hostage situation: URL',
#  650254360727973889: '5p bag charge fi dead #robthisengland URL',
#  544329935943237632: 'uber sydney trips from cbd will be free for riders. higher rates are still in place to encourage drivers to get into the cbd.',
#  693586539562037248: 'what a rally for no. 1. oklahoma came back from 14 down and won 77-75 at lsu on this late jumper: URL',
#  764497123530375169: 'man armed with knife on swiss train starts fire - seven people hospitalised with knife wounds and burns, police say URL',
#  724939017410727938: '500,000 boycott target over trans bathroom policy... URL',
#  651044059222556674: 'the best thing about the 5p plastic bag charge is that the cupboard next to my sink is now worth £672,348.',
#  552802654641225728: 'charlie hebdo shooting latest: 12 dead and gunmen still at large URL URL',
#  723477822950395904: 'purple pain: landmarks across globe light up in fitting prince tributes #ripprince URL URL',
#  544305540286148609: 'a man believed to be the gunman filmed wearing a black headband inside the cafe URL URL',
#  693906624776245249: "today's the day: if you don't have health insurance, make sure you #getcovered at URL now! URL",
#  524923462398513152: "shots fired on parliament hill after a man walked up with a gun. i'm locked in a security office on parliament hill",
#  763896522790440960: 'layton police officer hospitalized after subway worker serves him meth and thc in his drink (video) URL',
#  616421546702336000: 'woah, nature. URL URL',
#  524944399890124801: 'recap: gunman shot dead inside parliament buildings; police believe there may be others on loose. cdn soldier shot earlier at war memorial.',
#  686657138270277634: 'photos of the day URL URL',
#  544391176137089024: 'hostage taker in sydney cafe demands isis flag and call with australian pm, sky news reports. URL #sydneysiege',
#  524969201102901248: 'mps credit sergeant-at-arms for saving lives in parliament hill shootings URL URL',
#  756690088533393409: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  767807335691653120: 'these louisiana politicians are demanding flood aid, but voted against sandy relief URL URL',
#  552806757672964097: 'update: 12 now confirmed dead in #charliehebdo attack in paris, @ap is reporting. story: URL (ap) URL',
#  693761289601060864: 'at least 30 people killed in double blast near shia shrine of sayyida zeinab, south of damascus - syrian state media URL',
#  544350567183556608: 'we can see people coming out a firedoor near the lindt cafe to waiting police. 2-3 people. hard to see. #sydneysiege',
#  758825535480864769: 'hillary clinton is lying. clinton is not first woman nominated for president. it was victoria woodhull in 1872. to … URL',
#  707300612862566400: 'obama to skip nancy reagan’s funeral, attend entertainment festival instead URL URL',
#  693080409282846720: '.@potus will make his latest push to advance equal pay for women today URL URL',
#  614593386188828672: 'white house lit in rainbow colors following us supreme court ruling that same-sex couples have right to marry. URL',
#  692665281362202624: "we've devoted 24 pages to #batman v #superman, interviewing @zacksnyder, @benaffleck, henry cavill, @galgadot... URL",
#  767129248045948929: '‘i can’t do this anymore,’ think 320 million americans quietly going about day URL URL',
#  692701223326056449: "we hope you're as excited about thursday as this kid was about lebron's easy basket: URL",
#  732981604826677249: "target says boycott over transgender bathroom policy isn't hurting sales URL",
#  692753210692476928: 'french police still searching for woman who may have been accompanying 28-year-old man arrested at disneyland paris URL',
#  650046859537448960: 'an openly gay man said that he and his partner met with pope francis a day before kim davis did URL',
#  693171092555431936: 'watch: tommy chong made a pro-bernie sanders video URL URL',
#  693546915892428800: 'jeb bush campaign kicks off 3-state farewell tour with iowa town hall meeting URL URL',
#  544269749405097984: "breaking: live coverage of hostage situation unfolding in sydney's martin place URL URL",
#  760109079133990912: '“after school satan clubs”? URL',
#  779633844680962048: "this network of tunnels is from the stone age however no one knows how they could've been constructed at the time URL",
#  765859710503378944: 'top north korean diplomat who disappeared from london embassy has defected to south korea, seoul confirms URL'}

# %% [markdown]
# preprocess(twitter15_text[656955120626880512])

# %%
twitter15_text
# Out:
# {656955120626880512: 'correct predictions in back to the future ii URL',
#  615689290706595840: ".@whitehouse in rainbow colors for #scotusmarriage? here's what i think about that decision: URL",
#  613404935003217920: 'cops bought the alleged church shooter burger king hours after killings URL',
#  731166399389962242: '🔥ca kkk grand wizard 🔥 endorses @hillaryclinton #neverhillary #trump2016 URL',
#  714598641827246081: 'an open letter to trump voters from his top strategist-turned-defector URL via @xojanedotcom',
#  614467824313106432: 'god put a rainbow over the white house 🌈 URL',
#  715515982584881152: 'craigslist ad: ‘get paid $15 an hour to protest at the trump rally’ - URL URL',
#  693315824132685824: '#quasimodo: dog with short spine has big heart URL URL',
#  693843042546106369: 'need to #getcovered? most people can find a health insurance plan for as little as $75/mo: URL URL',
#  622891631293935616: '#wakeupamerica🇺🇸 who needs a #gun registry when #obama has all your personal information URL URL',
#  692630756548591616: "japan's economy minister akira amari resigns over corruption allegations URL",
#  693265096278163456: 'german shepherd with a rare spinal condition looking for a forever home. URL URL',
#  553589051044151296: 'several hostages freed at jewish supermarket in paris. photo thomas samson #afp URL',
#  553590835850514433: 'hostage-taker in supermarket siege killed, reports say. #parisattacks URL URL',
#  622858454949040128: 'in heaven chick-fil-a is open on sundays.',
#  656870311057575936: 'the 5 most accurate predictions from the decade-jumping adventures in #backtothefuture: URL URL',
#  616311563071434753: "apologies if you've already seen a crow riding a bald eagle today. image: phoo chan story: URL URL",
#  641666167992647681: 'oh, you invented the pencil? #appleevent URL',
#  525060425184858112: "the canadian soldier killed in today's ottawa shooting is cpl. nathan cirillo, a family source told cnn. live blog: URL",
#  672513234419638273: '"thoughts and prayers are not enough." pres. obama speaks on mass shootings over the years: URL URL',
#  544382892378714113: 'five hostages escape sydney cafe siege — live updates from @buzzfeedoz URL URL',
#  681824512120324096: 'when she heard about south korean "comfort women," @yunghi photographed some survivors URL URL',
#  620835698514464768: 'translucent butterfly - beautiful! URL',
#  626898253900943360: 'everyone mad at bruce for his sex change but no one gave ashit about that nerd minkus changing into chanel west coast URL',
#  618804516578680832: "family: @schwarzenegger's last act as governor stole justice from dead son. URL URL",
#  672632899921833984: 'why have there been more mass shootings under obama than the 4 previous presidents combined? URL URL',
#  553588178687655936: 'reports: #charliehebdo suspects killed URL',
#  594687353937100801: 'the kissing islands, greenland. URL',
#  613016993692798977: 'police chief says dylann roof was taken to burger king shortly after arrest URL',
#  663385747177775105: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  766715993385267201: 'russian olympic officials concerned after learning team’s clean urine reservoir almost empty URL URL',
#  693141729529184256: "it's 2016. women should earn the same pay as men for doing the same work. URL #equalpay URL",
#  524966904885428226: 'breaking update: canadian soldier injured at parliament hill shooting dies URL #ottawa',
#  613393657161510913: 'cops bought burger king for dylann roof following his arrest URL URL',
#  544374511194632192: 'update: total of 5 people have been able to get out of sydney cafe during hostage situation: URL URL',
#  706665777332621314: '.@berniesanders: in 2016, "we will end institutional racism and reform a broken criminal justice system.” #demdebate',
#  693827886021767169: '"our high school graduation rate is at an all-time high." —@potus URL URL',
#  604354747357859842: 'florida couple arrested for selling fake real estate on the moon #wtf15 👉🏿👉 URL URL',
#  767709416879644672: '"i hate writing; i love having written." dorothy parker was born on this day in 1893: URL',
#  693146363685642240: "watch one direction's original #xfactoruk auditions from 2010, where it all began URL URL",
#  652783670370115585: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  674187250792558592: 'donald trump v adolf hitler URL',
#  726043971911213057: 'target boycott crosses 1 million signers, stock sinks by $1.5 billion URL',
#  524935485370929152: 'shooting in canadian parliament comes day after isis-inspired radical drove in2 canadian soldier. also reports of shooting at war memorial/1',
#  730939370765754368: 'ca grand dragon endorses hillary clinton on behalf of the kkk. #trump2016 URL URL',
#  723365789378584578: 'landmarks around world turn purple, in honor of #prince. #princerip #purplerain URL',
#  674244561519161344: '"you\'re increasingly compared to hitler. does that bother you?" trump: "no." URL',
#  553535829017370625: '#breaking - at least five hostages in paris kosher supermarket: (afp) URL #vincennes URL',
#  731093044460683264: 'target ceo responds to nationwide boycott of the store over transgender bathroom policy URL URL',
#  693086218276474880: "oh, i'm so ready to watch @zaynmalik's #pillowtalk on mtv tonight at 8:15p. URL URL",
#  692150118921957376: 'jeb bush campaign kicks off 3-state farewell tour with iowa town hall meeting URL URL',
#  656830586577883136: "happy #backtothefuture day! how did 'back to the future: part ii' score on 2015 predictions? URL URL",
#  553543369604210689: 'an 11-month old baby is among the hostages at the kosher supermarket in paris. unbearably sad. URL',
#  767814876433571840: 'rudy giuliani rips @hillaryclinton for dragging colin powell into email scandal: "she lies every day." URL',
#  649985459389661184: 'an openly gay man said that he and his partner met with pope francis a day before kim davis did URL',
#  553531413459660800: 'update - afp says gunman who has taken a hostage at kosher supermarket in paris believed to be suspect in killing of policewoman on thursday',
#  693840291992838147: 'isis claims responsibility for triple bombing that killed at least 45 people and injured more than 100 near damascus. URL',
#  663925546812837888: 'solo cups have been red for decades. if starbucks was taking a shot at christmas, solo shot first.',
#  614604054552018944: 'the @whitehouse is rainbow-colored tonight in celebration of scotus same-sex marriage ruling. URL URL',
#  637382230394822656: 'ben carson: what happened to blacks during slavery is why i am pro-life on abortion today URL URL',
#  661222523275636736: "anonymous to kkk: you can hood, but you can't hide. #opkkk #hoodsoff URL",
#  714531423273746432: 'an open letter to @realdonaldtrump from his top strategist-turned-defector: URL URL',
#  675043569367982081: '‘el chapo’ threatens #isis: ‘my men will destroy you’ - URL URL',
#  544314234541469696: 'uber intros surge pricing in downtown sydney during hostage siege URL URL',
#  651809229842608128: 'avoid 5p bag charge using these from @trolleybagsuk enter here to #win a set with @star100x URL URL',
#  693140340367187969: 'chiefs te travis kelce will have his own reality tv dating show: URL URL',
#  553534838880608256: '#breaking gunman in policewoman killing suspected in new paris hostage-taking: source',
#  633961125126668288: 'a new cnn/orc poll finds @hillaryclinton ahead of @realdonaldtrump by just 6 points URL URL',
#  544512108885725184: 'paramedics are currently carrying out a number of hostages in #martinpl. #sydneysiege #9news',
#  552805488631758849: "at least 12 killed in today's attack on satirical magazine #charliehebdo in paris, official says. URL",
#  645711628046995462: "latest starving 'refugees' from #syria . these guys look like friggin soldiers to me! URL",
#  614608936491188225: 'white house lit in rainbow colors after gay marriage ruling URL URL',
#  693858804279201794: 'poor women in india are fighting for the right to have a job. "when you start working, your heart opens up." URL',
#  674014933235859456: 'dearborn michigan, this morning. pro isis rally. spread the word, the fit is about to hit the shan here in the us. URL',
#  690042063958732800: "#ausopen: british number one andy murray beats australia's sam groth 6-0 6-4 6-1 scores: URL URL",
#  693041285087756288: 'saliha is one of the first women ever to stand for election in saudi arabia: watch her story URL URL',
#  620971220301787136: 'while @cnn is talking about #irandeal nasa confirms earth will experience 15 days of darkness in november 2015 URL',
#  656880145769197568: "10 'back to the future' predictions that came true URL URL",
#  674263945172119552: "1.15 million americans have been killed by guns since john lennon's death URL URL",
#  612646796355960832: 'after arrest, dylann roof was hungry. police bought him food from burger king. more details: URL URL',
#  544511199702822913: 'police move in: police confirm live ammunition used in martin place #sydneysiege',
#  650952376954650629: 'pathetic little twat can’t wait to argue over 5p bag\xa0charge URL URL',
#  693441093048766464: "icymi: joseph pena squatted 875 pounds. he's 17 years old ... URL",
#  553107921081749504: 'two shot in paris, including traffic cop, as manhunt continues for #charliehebdo suspects URL URL',
#  666190716448587776: 'warning syrian refugees hv arrived in neworlean &they r here 2stay ur funds r being well invested in one-way tickets URL',
#  681199637387149313: 'sacha baron cohen and his wife donate $1 million to syrian refugees URL URL',
#  632377165477191680: 'trayvon martin at space camp in florida. #blacklivesmatter URL',
#  652992524504600576: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  763738618573623297: 'hillary clinton strategist bob beckel called for wikileaks editor julian assange to be assassinated: i do not... URL',
#  672927317191229440: 'this is the face of female jihadist #tashfeenmalik could pass for a widow or orphan😤#norefugees #islamistheproblem URL',
#  757367391202471937: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  688819658057740290: 'us trying to locate americans missing in baghdad after al-arabiya reports they may have been kidnapped by militias URL',
#  692845716826300418: 'today, the @deptofdefense took steps to expand paid leave for military moms and dads → URL URL',
#  756282236375277568: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  692748411481780224: 'man held at disneyland paris carrying "low-calibre" guns & copy of koran - police sources URL URL',
#  675193315306905600: 'el chapo vs isis: mexican cartel boss threatens islamic state over drug trade URL URL',
#  674364257799004160: 'adolf hitler vs donald trump URL',
#  716461257025581056: '.@berniesanders is pulling magic tricks out of a hat in nevada. we just officially won! URL',
#  662430295254175744: '#opkkk releases 500+ names and reveals unexpected #plottwist URL URL',
#  544512676643500033: 'breaking @skybusiness: freed hostage borne high from #sydneysiege w/c.4 paramedic teams on the scene URL ( carsonscottli',
#  638050997340893184: 'in celebrity death hoax news, james earl jones is not dead. URL URL',
#  692890520960397312: 'the terps do it again! no. 8 maryland knocks off no. 3 iowa 74-68, has beaten 5 of its last 7 top-5 opponents. URL',
#  544324444773433348: 'uber says it has hiked prices in sydney to "encourage more drivers to come online & pick up passengers." URL #sydneysiege',
#  745236050407194624: "the big one: 'large scale motion' detected along san andreas fault URL URL",
#  673079581520318464: 'do these look like the faces of a homeless couple caught living in a walmart attic for 2 years? URL',
#  691995324752252930: '"the dave i know is polite, modest, and content. jumbotron dave is crass and loud." URL URL',
#  673984270902427650: 'donald trump and adolf hitler. two sides of the same coin. #racism #fascism URL',
#  524975705206304769: "#nhl cancels tonight's game between #ottawa and #toronto due to today's shootings. senators were to host maple leafs.",
#  618805892222468096: 'jay z and beyoncé want to buy rights to the confederate flag: URL URL',
#  693086478667112448: 'the people have spoken: there is now a petition for @snoopdogg to narrate "planet earth" URL URL',
#  614595181845839873: 'the white house is lit up rainbow. URL',
#  654371696195993600: 'colorado mcdonald’s offers first marijuana friendly smoking section in restaurant - URL',
#  665358434351509504: 'breaking: 1st load of 10,000 syrian refugees arrived in new orleans URL #makeamericagreatagain URL',
#  755439197125767169: 'ohio police say an officer was served a sandwich containing glass shards at a restaurant. URL',
#  666633171325353989: 'the myth of zouheir, a "hero muslim security guard" in paris URL (via @bbctrending) URL',
#  729647367457230850: 'leading causes of death in the u.s.: 1. heart disease 2. cancer 3. medical error URL URL',
#  726442550266044416: 'because target believes men can pee with girls, their stock has taken a huge hit. good. keep boycotting target. URL',
#  666070802924617728: 'jindal demands info about refugees entering new orleans... URL',
#  544512664769396736: 'breaking: police enter #lindt cafe, hostages flee URL #sydneysiege URL',
#  692106491365605376: 'apple announces most profitable quarter in u.s. history—and the end of unprecedented growth URL URL',
#  727966590084485120: '.@caitlyn_jenner will reportedly pose nude for sports illustrated URL URL',
#  691789524498845699: 'president obama announces ban on solitary confinement for juveniles in federal prisons - washington post URL',
#  767803368081358848: 'fbi uncovers nearly 15,000 more emails and materials sent to or from hillary clinton. URL URL',
#  667379734343471104: 'donald trump is the new adolf hitler URL',
#  715671763808493569: "☆☆craigslist ad allegedly posted by bernie supporters offered $15 to protest at trump's rally in wisconsin. trump already creating jobs!",
#  653250169752977408: '.@hillaryclinton is ahead of @berniesanders by 19 percentage points, in a new cbs news poll released sunday. URL',
#  656361703664451585: 'well done scotland! 5p carrier bag charge 1 yr old today - 80% cut in usage - 650m less bags -£6.7m for good causes. URL',
#  643103859729166337: 'unreal: watch what happens when desperate muslim refugees are offered red cross food URL URL',
#  714560810266132480: 'letter to trump voters from his top strategist-turned-defector - i don’t know if this is real, but it’s believable. URL',
#  658065957823324160: 'the father of steve jobs, the ground-breaking founder of apple, was a refugee from syria URL URL',
#  693534670428971008: 'up to 100 masked men, dressed in black, involved in "migrant attack" in stockholm URL URL',
#  722885778448121857: "a new transgender bathroom policy at @target is real, and it's fabulous: URL URL",
#  614599619310407680: "white house is aglow in the colors of the rainbow celebrating the supreme court's same-sex marriage decision. URL",
#  706933939953344514: 'bernie sanders speaking about institutional racism 👏🏽🙌🏽 URL',
#  691285663522648065: 'investigations into nearly 60 allegations of unlawful killing against uk soldiers in iraq are dropped, mod says URL',
#  661229627734667264: 'mayors flatly deny klan membership after #anonymous releases names online URL #opkkk #hoodsoff URL',
#  714755546285477888: "donald spunktrumpet's former communications director stephanie cegielski has resigned and written this - URL",
#  672102358516670465: 'holy christ, #samuraijack is returning to television! URL URL',
#  673686233936072704: '72 dhs employees on the terror watch list: URL h/t @penguinsfan62',
#  618192748735299584: 'the kissing islands, greenland! URL',
#  715264793737879553: "donald trump supports abortion ban and 'punishment' for women URL",
#  614594667225571328: 'breaking: the @whitehouse is celebrating with us tonight lit up in rainbow colors. #lovewins URL',
#  693935557009801218: "iran's supreme leader awards medals to troops who 'captured' u.s. sailors URL URL",
#  644229386149888001: 'greek customs captured containers of weapons and ammunition going to refugee camps in europe as "plastic furniture" URL',
#  763428684850094080: 'breaking video : hillary surrogate calls for the assassination of julian assange. URL',
#  671181758692507648: 'desperate ted cruz claims planned parenthood shooter was transgender leftis; based on rumor he read URL',
#  692078399012130816: 'woman a leading authority on what shouldn’t be in poor people’s grocery carts URL URL',
#  752875379765968897: 'ted cruz is apparently riding with the president on air force one en route to dallas. man, barack obama is a saint.',
#  626642648179159040: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  742114513726623744: 'a tweet from @realdonaldtrump about the #orlando shooting: URL URL',
#  716457799392342018: 'bernie sanders has actually won nevada, not hillary clinton! the people have spoken! URL URL',
#  778625026144792577: 'massachusetts court finds that it’s ‘reasonable’ for black men to run from police to avoid racial profiling… URL',
#  614610920782888960: 'there will be cool photos of the white house w rainbow colors tonight but hard to top this one by chuck kennedy. URL',
#  715254040289021952: 'donald trump tells chris matthews: women deserve ‘some form of punishment’ for abortion URL URL',
#  673872171341447169: '72 dhs employees on terrorist watch list URL via @kredo0 URL',
#  693167683701968896: "women in america still earn only $0.79 for every $1 men make. it's time for #equalpay → URL URL",
#  724624672604610562: "people are over here boycotting @target over their new transgender bathroom policy and i'm just like URL",
#  655432919595548672: "thousands of people in china claim they have seen a 'floating city' in the sky URL",
#  692014905239666688: "danish lawmakers approve bill allowing seizure of asylum seekers' valuables to help cover expenses. URL",
#  544520042810200064: '#sydneysiege is over. 2 confirmed dead, #prayforsydney #prayforsydneyhostages #sydney #hostages',
#  692803280238419971: 'usgs: sonic boom confirmed in new jersey area after reports of shaking; cause not immediately known URL',
#  664000310856310784: 'mysterious creature discovered in california, everyone naturally cries alien: URL URL',
#  742571519105077248: "considering the #orlando shooter was a registered democrat i'd like to just put these back here: URL",
#  767541796410839040: "powell breaks silence: clintons trying to 'pin' scandal on me! URL",
#  641972184412327937: 'alert! islam taught in tennessee schools URL #wakeupamerica #tcot #wethepeople #pjnet #ccot URL',
#  651321040119963648: 'el chapo puts $100 million bounty on donald trump...dead or alive! URL',
#  662151653462790144: "hackers from anonymous say they're set to expose hundreds of kkk members URL #opkkk URL",
#  693844030589902848: '.@dylanobrien learned the hard way to not mess with @shelleyhennig: URL URL',
#  676067381299576832: '72 dhs employees on terrorist watch list - washington free beacon URL',
#  544491151118860289: 'sydney hostage-taker - man monis, 49 - originally from iran - self-styled sheikh - accused of sexually assaulting 7 women developing..',
#  544515538383564801: 'haron monis,hostage-taker in #sydney: fled #iran 96,suspect in ex-wife killing,46 sex assaults URL URL',
#  673615400655970304: "shock: 72 'homeland security' employees on terrorist watch list... URL",
#  653432261203750912: 'why drunk vegetarians eat meat URL via @thedailybeast',
#  641443248909754368: "kim davis angers 'eye of the tiger' creator after using song at prison release URL",
#  614601139422633984: 'white house lit in rainbow colors following us supreme court ruling that same-sex couples have right to marry. URL',
#  524931324763992064: 'very reliable source on parliament hill tells me the assailant has been killed. #cdnpoli #ottnews',
#  707786906189303808: "meet kenny the tiger. he was born with down syndrome. he's proof you don't have to be perfect to be beautiful ❤️ URL",
#  656047932093763584: 'cnn/orc poll: clinton did best in 1st dem debate, but only sanders significantly increased support in past month. URL',
#  723025600810766336: '#ripchyna: the wwe icon has passed away at the age of 45. URL URL',
#  656595123590012928: "10 'back to the future' predictions that actually came true URL URL",
#  615346611955183616: 'breaking: south carolina to ban sale of tylenol. they fear picking of cotton from the bottles may represent slavery. URL',
#  763524712853102596: 'hillary clinton strategist bob beckel called for wikileaks editor julian assange to be assassinated. #dncleaks URL',
#  663817239896821760: 'for everyone who thinks starbucks red cups are ruining christmas URL URL',
#  659462980476637184: 'fda confiscates several thousand chickens from kfc farms as mutations worsen URL URL',
#  669259395902152704: 'months ago, rupert murdoch bought national geographic and fired most of writers. this just hit the stands. URL',
#  620367840902782976: "translucent butterfly - beautiful! ' URL",
#  733242244522725376: '🎯 #target backlash over transgender bathroom policy hits "boiling♨️point"❗️ URL #boycotttarget URL',
#  544301453717041152: 'breaking update: gunman says four devices are located around sydney. security response underway. police calling for calm. 9news',
#  628045645010608128: 'sylvester stallone was so broke before his script for rocky was accepted that he sold his dog for $25. after he bought it back for $15,000.',
#  672169954016403456: 'pres. obama on #sanbernardino: "we have a pattern now of mass shootings in this country that has no parallel." URL',
#  693076140278153217: 'michael phelps\' gold medals and speedo crashed asu\'s "curtain of distraction" last night. you read that right. URL',
#  674314254732931072: '.@presssec: @realdonaldtrump comment "disqualifies" him from presidency URL via @talkopan URL',
#  714555825122107392: 'an open letter to trump voters from his top strategist-turned-defector URL @juddapatow @andylassner @bettemidler',
#  611039775856812032: "what's lurking underneath that crispy crust? a kfc customer claims he got a fried rat: URL URL",
#  778681502825451520: 'black men have legitimate reason to run from police – #massachusetts supreme court URL URL',
#  525068915068923904: '***exclusive*** michael zahaf-bibeau caught on a #dashcam model sold at URL #ottawashooting URL',
#  740791134146965504: "dear @hillaryclinton you're not the 1st woman presidential candidate. victoria woodhull is. look @realdonaldtrump URL",
#  544504183341064192: 'escaped #sydneysiege hostage, elly chen, a top student and skilled sportswoman URL URL',
#  553476490315431937: 'police convoy and helicopters are rushing to scene to detain charlie hebdo massacre suspects URL URL',
#  761573188543229952: 'good news: our businesses have added 15 million jobs over the past 77 months → URL URL',
#  673696115305406466: '72 dhs employees on terrorist watch list URL',
#  651825062174195712: 'ben carson is the most brainless brain surgeon in america. my new column: URL',
#  633949800761700352: 'cnn/orc poll: donald trump now competitive in general election URL via @jennagiesta URL',
#  761999790892806144: '“our team boasts the most women who have ever competed for any nation at any olympic games.” —@potus on @teamusa: URL',
#  553587013409325058: "#breaking charlie hebdo gunmen's hostage freed and safe after police assault",
#  544513524438155264: 'sydney siege: police enter cafe as hostages flee the scene, gunfire heard, reports of an injured person – live URL',
#  672539897899577344: 'mass shootings list. reagan - 11 bush sr - 12 clinton - 23 bush jr - 16 obama - 162 #sanbernadino',
#  693691456222052352: 'red alert! drake just dropped a new single called, "summer sixteen" from his new album. URL URL',
#  693648684857323521: 'spoiler alert: leo and kate were ridiculously cute together at the 2016 #sagawards. URL URL',
#  655812191233417216: 'when refusing to pay the 5p bag charge backfires URL 😂🙈',
#  672219174463275008: 'pres. obama on #sanbernardino: "we have a pattern now of mass shootings in this country." URL URL',
#  614628865353351168: 'the white house takes on rainbow hues in celebrating #scotusmarriage decision: URL URL',
#  727854332188577792: 'perhaps media should ask hillary about this clinton campaign made payments to hard drive destruction company URL',
#  544358564484378624: 'police: negotiators are now in contact with armed hostage-taker in sydney situation; motive remains unknown - URL',
#  742012307694223361: '#orlando oh look the muslim shooter was also a democrat! URL',
#  707332312724283392: "obama to skip nancy reagan's funeral for music, film festival in austin, tx URL via @waynedupreeshow",
#  755447443009916929: 'police shut down restaurant after officer cuts mouth on shards of glass found in sandwich URL URL',
#  693555965019492352: 'denver medical center on lockdown; 9 at hospitals after deadly incident at denver coliseum URL URL',
#  705092738224525312: 'breaking news: search "how can i move to canada" skyrocketed following #supertuesday URL',
#  724661834419048448: "hey guys, target isn't backing down check the usa today article about the boycott URL",
#  757190314880884736: 'donald trump: "...laziness is a trait in blacks. it really is, i believe that. it’s not anything they can control.” URL',
#  544278985249550337: 'geoblock lifted on #abcnews24. streaming coverage of the martin place siege in sydney here URL',
#  544367462012432384: 'more: police confirm 3 hostages escape sydney cafe, unknown number remain inside URL #sydneysiege',
#  775672628493357057: 'clinton hides failing health? full disclosure now: covert doctors and nurses URL via @mailonline #maga @realdonaldtrump',
#  692797856386777089: 'an adorable young fan asked riley curry to be his valentine ... and steph responded: URL URL',
#  614645853291155457: 'as sun goes down, white house lights up rainbow colors to celebrate scotus ruling: URL URL',
#  682916727282270208: "erdoğan cites hitler's germany as example of effective government URL",
#  725983128444129280: 'starve the beasts destroying our #civilsociety #target stock ➡️ sinks $1.5 billion URL URL',
#  766808183696351233: '"laziness is a trait in blacks"-trump, according to former president of trump plaza hotel and casino @vitico46 URL',
#  552791196247269378: "breaking: at least 10 killed in shooting at french satirical newspaper charlie hebdo, paris prosecutor's office says. URL",
#  524943490887991296: 'confirmed | 1 shooter shot dead at parliament hill, but there is more than 1 suspect. #cbcott #ottnews',
#  667534186450825216: "steve jobs' biological father was a syrian immigrant.",
#  687643002240679936: 'three men found guilty of involvement in "largest burglary in english legal history" at hatton garden URL',
#  723511860516016128: 'all in purple: memorials and landmarks across the globe honor #prince after his death. URL URL',
#  677099574855639044: 'plumber suing car dealership for $1m after truck he traded in ends up in hands of isis: URL URL',
#  544391533240516608: 'five hostages have escaped the besieged lindt cafe in #sydney | our latest update: URL URL',
#  656825206045020160: "#backtothefuture fans, it's october 21, 2015 — the future is finally here! URL URL",
#  525025279803424768: "the soldier shot dead in wednesday's ottawa attacks has been named as cpl. nathan cirillo of #hamont #ottawashooting URL",
#  693119705469587456: 'nasa astronaut @stationcdrkelly captures a beautiful sunrise from aboard the international space station. URL',
#  666051332504207360: 'jindal protests sending of syrian refugees to new orleans URL URL',
#  692929779696275456: 'ohio lawmakers want to know why state’s epa didn’t tell public about lead leaking into water supply of sebring. URL',
#  650975967146602496: "uk • you're right to be nervous about the 5p plastic bag charge. when they implemented this in california the streets ran red with blood.",
#  553544694765215745: "french police publishes photos of suspect in yesterday's montrouge shooting. maybe the same persons in kosher market URL",
#  674080899055546368: 'a vote for donald trump is a vote for adolf hitler.',
#  626770498328895488: "translucent butterfly - beautiful! ' URL",
#  657007736467525632: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  614626710248534016: '"these colors celebrate a new chapter in the history of american civil rights." #lovewins URL URL',
#  751536167183613952: "#urgent so-called 'purge' planned tonight in baton rouge 1200am - 0500am. #bluelivesmatter - heres the flash >> URL",
#  693771953648373760: 'in china, 77% of jobs are threatened by automation URL URL',
#  649903655160815616: "vatican says #kimdavis' meeting w/ #popefrancis 'should not be considered a form of support.' URL URL",
#  692082861525078017: 'tony the tiger has no more cummies left to give URL URL',
#  614054616154550273: 'charleston church shooter dylann roof receives $4 million in donations from supporters - URL URL',
#  674301960787505153: 'donald trump has been disqualified for running for president URL',
#  658755852199927808: 'test finds human dna in hot dogs, meat in vegetarian products URL URL',
#  748543642323783681: 'obama cuts military pay third year in a row, while pushing $15 min. wage for burger flippers URL URL',
#  614494170590367744: "theres' a double rainbow over the white house URL",
#  661870323034431489: 'holy shit. rupert murdoch just killed national geographic. URL',
#  637873886072320001: 'sanders closes to 7 points behind clinton in new iowa poll. URL URL',
#  732004388181434368: 'target’s new transgender policy raises all sorts of questions. URL',
#  689938201193115648: '.@potus on declaring a federal emergency in #flint, michigan to supplement state and local response efforts. URL',
#  645362146415525888: '#bulgaria finds 10,000 #fake passports hidden by #muslim refugees heading for #germany passports for #terrorists URL',
#  692758581494599681: 'french police hunting woman who was with an armed man arrested near disneyland paris. URL',
#  672632863452299264: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  727187859367546880: 'good news!: target stock plummets #lbgtq #bathroombill URL #tcot #pjnet #rednationrising URL',
#  764931593303646208: "fox news host claims hillary clinton had seizure on camera, has 'secret' health issues URL URL",
#  525056576038518785: 'soldier killed in canada shooting was a young reservist with a six-year-old son URL URL',
#  672433211604013057: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  747275598347837440: 'newsflash⚡️the #orlando shooter was a muslim and a democrat✔️ not a republican or christian❌ #gaypride2016 URL',
#  774833492865593344: 'nurses save lives of all different races and colors, but @hillaryclinton thinks we belong in a #basketofdeplorables. URL',
#  760928376668454912: 'before hillary clinton, there was victoria woodhull, a pro-life feminist who ran and was nominated for president. URL',
#  728013148788154368: 'report: caitlyn jenner will pose nude for sports illustrated URL URL',
#  614618682543616000: 'white house shines rainbow-colored lights in honor of #scotus gay marriage decision #lovewins URL URL',
#  693060960001597440: 'mark zuckerberg is now richer than the koch brothers 💰 URL URL',
#  693826104633737217: 'watch bernie sanders sing "this land is your land" with vampire weekend at iowa students rally URL',
#  723644048867774464: 'niagara falls turned purple on the day prince died: URL URL',
#  742050150307246080: 'shooter in orlando was: a. muslim b. registered democrat voter c. isis d. homophobic e. ready for hillary URL',
#  675064077367005184: 'el chapo threatens isis URL URL',
#  524926235030589440: 'breaking news: at least 3 shots fired at ottawa war memorial. one soldier confirmed shot - URL URL',
#  749286768554438658: "what's the no. 1 killer of americans? these rankings have changed little over the years URL URL",
#  544380742076088320: 'this is shot that captures the #sydneysiege: sheer terror/relief of escaped hostages, incredible work of @nswpolice URL',
#  614605997953404929: "white house lit in rainbow colors after high court's gay marriage ruling (with photo) URL",
#  629503919098429440: 'chick-fil-a to open on sundays URL',
#  692623941131722752: '3-legged dog expected to survive after getting shot while scaring off armed robbers. URL URL',
#  626546123713474560: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  672906198434209792: "farook family attorney says brothers in the family never saw tashfeen malik's face because she always wore a burka. URL",
#  673615263040798726: '72 dhs employees on terrorist watch list URL',
#  647169573599449088: "new cnn democratic poll: bernie sanders 46 hillary clinton 30 joe biden 14 martin o'malley 2",
#  641050980985999360: 'happy "$15 minimum wage" labor day from mcdonalds URL',
#  727179214546456577: "target's stock has taken a $2.5 billion hit over its insistence on insulting regular customers URL",
#  666107476526432256: 'muslim security guard stopped bomber from entering the stadium during #parisattacks URL #zouheir URL',
#  620916279608651776: 'nasa confirms earth will experience 15 days of complete darkness in november 2015 - URL URL',
#  673664899571060736: '72 dhs employees on terrorist watch list URL via @kredo0 URL',
#  544271284796784640: "developing: gunman takes hostages in sydney cafe, 'isis' flags being held against window - URL URL",
#  692071267189395457: "here's why @potus is taking steps to ban solitary confinement for low-level infractions: URL URL",
#  651486105628463105: 'black people can be so stubborn to change.... #5pbagcharge URL',
#  675065047710892033: 'mexican drug kingpin \'el chapo\' reportedly threatens to destroy isis "p*ssies." URL URL',
#  668144671772778497: 'according to anonymous, the next isis target is a wwe event in atlanta. URL URL',
#  604625816992002049: 'the kissing islands, greenland. URL',
#  682996350909157376: "turkey's president says all he wants is same powers as hitler URL URL",
#  688752927381581824: '"today’s progress...these things are a reminder of what we can achieve when we lead with strength and wisdom." —@potus on progress with iran',
#  693087220459270144: "4 miners now rescued from mine in china's shandong after 36 days underground - state media URL URL",
#  524962142563610625: '#breaking rick hughes at cbc hamilton: the soldier who was shot in ottawa wednesday morning is a reservist serving in hamilton',
#  693573781730783232: "ooh, baby! dickie v loved this reverse dunk by ben simmons. lsu's up double-digits on no. 1 oklahoma: URL",
#  692083780123783172: 'actor abe vigoda has died at 94 URL URL',
#  627828211003469825: 'this is how people in china are riding escalators after a horrific accident URL URL',
#  693059995013742592: 'mook spooked: hillary manager predicts trump will win presidency if nominated!',
#  614594195479752704: "white house lit in rainbow colors after today's historic supreme court ruling #scotusmarriage URL",
#  692691444046372865: 'zika virus "spreading explosively" around the americas, who director-general says. URL',
#  614593989203886080: 'the @whitehouse is lit up like a rainbow! #lovewins URL',
#  690376107825192960: 'happy #nationalhugday! URL',
#  658259426172891136: '4 legged chickens: fda confiscates several thousand chickens from kfc farms as mutations worsen URL',
#  676586804242309121: 'isis has been killing babies afflicted with down syndrome and other disabilities, activists claim URL',
#  651959206287908868: "donald trump's capture, dead or alive, is reportedly worth $100 million to el chapo. URL URL",
#  681147789653356544: 'katy perry -- makes holiday wish come true for burn victim URL',
#  652882609219833856: ".@realdonaldtrump: what's the secret of my popularity? my looks. i'm very handsome. URL URL",
#  544476808566276097: "tv channels have chosen not to show videos of hostages relaying #sydneysiege gunman's demands. URL URL",
#  687274510643511296: 'the oregon militia idiots would like you to stop mailing them dildos, please URL URL',
#  647464349611589632: 'poll: @hillaryclinton trails @berniesanders in new hampshire, even without @vp in the race URL URL',
#  726086935903494144: 'target boycott crosses 1 million signers, stock sinks by $1.5 billion - breitbart URL',
#  691632238035886081: 'former conservative minister lord cecil parkinson dies aged 84, after suffering from cancer, his family says URL',
#  524952883343925249: "watch video showing gunfire inside canada's parliament in ottawa URL URL",
#  688021039322894336: 'kosovo war crimes court to be set up in the hague, dutch government says URL',
#  707308274270539777: "no one is surprised by this.of course obama is skipping nancy reagan's funeral.dignity isn't his strongest attribute URL",
#  691678576018657281: 'adorable but frightened sloth rescued from side of highway in ecuador URL URL',
#  692874200927698945: 'report: las vegas sands to propose $1 billion domed stadium to possibly draw nfl franchise - fox5 las vegas URL',
#  666640008149925893: 'son of a syrian refugee URL URL',
#  663515735231062016: 'michelle obama says ‘white folks’ are what’s wrong with america URL no michelle you are whats wrong with america',
#  643139873264812032: 'and so it begins…isis flag among refugees in germany fighting the police [pictures] URL URL',
#  689860942671130624: "7 years ago, @potus bet big on rescuing the american auto industry. here's how it paid off: URL URL",
#  656662726014599168: 'the father of steve jobs, the ground-breaking founder of apple, was a refugee from syria URL URL',
#  674229534888185856: 'who said it: donald trump or adolf hitler? URL URL',
#  716424773216022530: "it seems @berniesanders has won back nevada! don't let @clarkcountynv dems rig it against @sensanders! #feelthebern URL",
#  672432930426372096: 'ever wonder why the most mass shootings ever have happened under obama? URL via @rebootliberty URL',
#  600451916414484480: 'nasa recently released imagery showing the deforestation of america …in just 34 years. URL',
#  692838430783332357: "nation's dog owners demand to know who's a good boy URL URL",
#  717081129627553792: "this is kenny, the tiger with down syndrome. this proves you don't have to perfect to be beautiful ❤️ URL",
#  765612862681255936: '.@greysabc season 13 will focus on the "originals" URL #greysanatomy URL',
#  641088973717110784: '#imachristianbut i wish chick-fil-a was open on sundays.',
#  652349108653551616: 'surprising number of vegetarians secretly eat meat URL URL',
#  777710439870455808: 'all living ex-presidents warn against donald trump URL URL',
#  553508098825261056: 'police have surrounded this building where the suspected #charliehebdo attackers are holed-up URL URL',
#  762793077509464064: '"if you could compete in any olympic event, what would you choose?" —@potus asks @flotus: URL URL',
#  614628136634949632: 'the @whitehouse is lit up in a rainbow #lovewins URL',
#  580324027715063808: 'just in: germanwings plane crashes in southern france, up to 150 feared dead URL',
#  634665777400950784: 'translucent butterfly URL',
#  674301413040758785: '.@presssec: @realdonaldtrump muslim comment "disqualifies" him from presidency URL URL',
#  613362193787129860: 'the kissing islands, greenland. URL',
#  743764020679741440: 'obama cuts military pay for third year in a row, while pushing for $15 min. wage for burger flippers: URL',
#  692820029159653377: 'beck on david bowie: "he’s always been a guidepost for me" URL URL',
#  693471161313816576: 'lego’s first-ever figurine in a wheelchair is prompting ‘genuine tears of joy’ URL',
#  716092408920936448: 'international criminal george soros & his boi @davidbrockdc are sooo busted #fauxprotests #ringers @realdonaldtrump URL',
#  524941132237910016: "here's that dramatic video via @josh_wingrove of shots fired inside parliament building: URL #ottawa #shooting",
#  727116900983934976: '. @target stock plunges in early days of @americanfamassc boycott. URL',
#  655986243042459648: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  544283772569788416: 'live updates: siege in sydney cafe URL',
#  693818562981421056: "icymi: somehow lebron came out in shorts that didn't match the rest of his team ... so he had to change mid-quarter. URL",
#  658938136299511808: 'human dna found in hot dogs - and 10% of vegetarian sausages contain meat URL URL',
#  618449248179191808: 'girl killed in her sleep from wearing earbuds while iphone was charging - URL URL',
#  693897857376632832: 'clinton ominously tells iowan supporters to mark front doors with campaign logo before sundown URL',
#  692410832307818497: 'will you watch thursday’s #gopdebate if @realdonaldtrump is not on stage? URL',
#  662381914842603520: 'rt @operation_kkk: official #opkkk #hoodsoff 2015 data release URL with love, anonymous . URL',
#  615494435074363392: 'if they can light up the white house like a rainbow for gay pride, it sure as hell better be red, white & blue for independence day. merica.',
#  763520953619918848: 'dear #msm bob beckel calling for assassination of #julianassange URL @ericbolling URL',
#  766568413418356736: 'us swimmer jimmy feigen to pay $11,000 to charity as part of deal to settle brazil robbery dispute - us media URL',
#  676367888543031296: 'north carolina town rejects solar panels for sucking "up all the energy from the sun.” URL URL',
#  692758050378256388: 'elvis presley made his tv debut 60 years ago today. look back at his history on the tube URL URL',
#  642465192408940544: '#wakeupamerica heads need to roll! school forcing non-muslims to praise islam URL #bansharia URL',
#  612438528803213312: 'after police arrested #dylannroof, they went and bought him burger king because he was hungry. #charlestonshooting URL',
#  613425834301485056: 'police bought #dylannroof food from @burgerking after he was arrested for church shooting: URL URL',
#  714567472712589312: 'how many more trump supporters will defect? an open letter to trump voters from his top strategist-turned-defector URL',
#  693281966846808064: 'a head-on collision with another planet may have created our moon, researchers say URL URL',
#  659428447459110912: '#opkkk: #anonymous to reveal identities of 1,000 ku klux klan members URL URL',
#  672902686380003328: 'reagan (11 mass shootings) bush sr (12 mass shootings) clinton (23 mass shootings) bush jr (16 mass shootings) obama (162 mass shootings)',
#  659439879701602304: 'fda confiscates several thousand chickens from kfc farms as mutations worsen URL URL',
#  553590459688570880: 'several hostages freed at jewish supermarket in paris. photo thomas samson #afp URL',
#  525058976376193024: 'our thoughts and prayers go out to nathan cirillo who died today in ottawa while protecting his country at age 24 URL',
#  669201837187334144: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  652300118205427716: 'survey: 1 in 3 vegetarians admits to eating meat when drunk... URL',
#  693203974388895744: 'a tiny alpine town in northern italy just welcomed its first baby in 28 years 🍼👶 URL URL',
#  747443219487678464: 'nyc pride parade after orlando: “republican hate kills" no. the orlando shooter was a muslim democrat. URL',
#  755548076438196225: 'colombus, ohio police officer served sandwich with shards of glass. URL',
#  728627623488786433: 'breaking: tom brady set to share sports illustrated cover with caitlyn jenner.... URL',
#  553476880339599360: 'developing: police pursuing #charliehebdo shooting suspects, helicopters deployed - live feed: URL URL',
#  749039299677417472: 'after the orlando shooting this is how they protest, and the shooter was a registered democrat... URL',
#  687537772970684417: 'jakarta attacks: #kamitidaktakut hashtag shows indonesians are not afraid URL',
#  725070832494624769: "boycott the hell out of target. they think it's ok that boys pee with girls so let's hit em where it hurts - money. URL",
#  728038172270198787: 'caitlyn jenner will pose nude on the sports illustrated cover. nothing says sexy like a 66 year old chick with balls.',
#  500378223977721856: 'oh. so now the #ferguson police chief says the cop didn\'t know about the robbery when he stopped #mikebrown. the kid was "jaywalking"? bs!',
#  724348906096590849: '340,000 pledge to boycott @target over transgender bathroom policy URL URL',
#  658786161733734400: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  728207861050970112: 'caitlyn jenner will pose nude on the sports illustrated cover. her balls will be censored by a sad michael jordan face.',
#  651402689352351744: 'help the red cross provide food, water & cots for refugees across europe. URL \xa0 #aidrefugees URL',
#  634943791934406657: 'marilyn monroe and james dean smoking in new york city URL',
#  544319832486064128: 'hostage situation erupts in sydney cafe, australian prime minister says it may be "politically motivated" URL',
#  693606934050684928: 'looking at eddie redmayne looking at alicia vikander is making us all kinds of emotional. #sagawards URL',
#  666810213274689537: 'but democrats say that syrian refugees are 3 year-old orphans. so why are they worried about them buying guns?',
#  692702295281262593: 'the @who predicts 3 to 4 million cases of #zikavirus that is spreading through americas URL',
#  692498490249891842: '"an attack on any faith is an attack on all our faiths." —@potus at @israelinusa',
#  689867195657101312: '13 questions with @madisonbeer, the 16-year-old singer @justinbieber discovered on youtube: URL URL',
#  553512735192141826: 'update - afp: an unnamed police source says the killing of the policewoman in #paris on thursday is linked to the #charliehebdo attack',
#  544517264054423552: '#breaking: police have confirmed that the #sydneysiege is over. #9news',
#  656629493377990656: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  663744139666804736: "as you ignore the cold homeless guy sitting outside starbucks, please be sure to complain about the 'non-christian' red cup of $5 coffee.",
#  675005503160901632: 'after mass shootings, obama seeks to expand background checks for gun sales by executive order to bypass congress URL',
#  638047610973089793: 'obese woman arrested for starving her 7 kids: "there was only enough food for me" URL URL',
#  727623131494387714: 'clinton campaign made payments to hard drive destruction company 🤔 destruction of 14 hard drives @hillaryclinton ⁉️ URL',
#  723198441690636288: 'pop legend prince has died at 57: URL URL',
#  641082932740947972: 'judy carne, ‘sock it to me girl’ on ‘laugh-in,’ dies at 76 URL',
#  648894687542034432: 'steve jobs was adopted. his biological father was abdulfattah jandali, a syrian muslim.',
#  692925396292091905: "paul kantner was jefferson airplane's conceptual heart. here are 12 essential songs URL URL",
#  752965545528528898: 'homicide is among the top five causes of death in adolescents URL #endviolence URL',
#  778572032531427332: 'massachusetts court finds that it’s ‘reasonable’ for black men to run from police to avoid racial profiling… URL',
#  716451800581279744: "it's official, @berniesanders actually won nevada today. came down to 2 factors. 1. enthusiasm 2. organization URL",
#  637868242560638980: 'woman stabs boyfriend for not liking instagram selfie fast\xa0enough URL URL',
#  498430783699554305: 'witness: police allegedly stopped mike brown after yelling at him to walk on sidewalk. #ferguson URL',
#  641430951403343872: 'translucent butterfly - beautiful! URL',
#  635632641635667968: "'great pacific garbage patch' researchers return with data URL URL",
#  652000523525091328: "a third of 'vegetarians' eat meat when drunk on a night out URL URL",
#  626897206717624320: "did a real life 'fallen angel' just fall from the sky in london? ‼️‼️ 👉 URL 👈 URL",
#  693476774462820352: 'merkel says refugees must return home once war is over URL',
#  626516248206135296: 'this is how people in china are riding escalators after a horrific accident URL URL',
# ...
#  544268732046913536: "#breaking: hostages are being held and a siege is taking place at sydney's lindt chocolat cafe in martin place.",
#  767855091109863424: '.@stephenfhayes: "this is about hrc having made repeated representations that have turned out to be false." URL',
#  692911086920667136: "in asu's curtain of distraction, michael phelps brought out his gold medals and speedo to do the trick. it worked. URL",
#  544282005941530624: 'hostages in sydney cafe made to hold up islamic flags URL',
#  614609560658161664: 'the white house is lit like a rainbow tonight in honor of the #scotusmarriage ruling. URL',
#  580348081100734464: '#germanwings "sorry to confirm" 144 passengers & 6 crew on board flight #4u9525 when it crashed in french alps URL',
#  723504069814444033: 'purple reign! landmarks light up for prince after his sudden death 💜 #princerip URL',
#  553586860334010368: '#charliehebdo killers shot dead by police',
#  640118021101604864: 'the insane reason why chinese drivers intentionally kill pedestrians they hit — via @slate URL URL',
#  688751061503442944: '"we have now cut off every single path that iran could have used to build a bomb." —@potus #irandeal URL',
#  778530869208190976: 'hillary overcharges poorest campaign donors @lindasuhler @realdrgina @girlsfortrump @cinderella2b @kamvtv #us #usa🇺🇸 URL',
#  544291804057960448: 'first photos: hostage pressed against a window. #sydneysiege URL',
#  688004802245214208: "study: minimum wage increases haven't hurt the restaurant industry. URL",
#  743126914794037248: "people blame the massacre in orlando on the nra. newsflash: the orlando shooter wasn't a nra member... but he was a registered democrat.",
#  653432177632387072: 'study finds over a third of vegetarians eat meat...when drunk! URL URL',
#  628604055644934144: "whole foods' selling asparagus water is a sign the end times are near URL URL",
#  692163879909064704: "#teenwolf starts in 5 minutes! rt if you're watching + tweeting + crying + screaming with @mtvteenwolf & me! URL",
#  728273551883534336: 'caitlyn jenner will pose nude on the sports illustrated cover. her balls will be censored by a sad michael jordan face.',
#  524942470472548352: 'the university of ottawa, just a five minute walk from the hill, is now on lockdown.',
#  552792544132997121: 'breaking charlie hebdo latest: 11 dead 10 wounded (five critical) two gunmen unaccounted for URL URL',
#  727834854931435522: 'evidence destroyed? campaign made payments to hard drive and document destruction company URL #makeamericagreatagain',
#  544289311504355328: 'statement from prime minister tony abbott on sydney hostage situation. URL',
#  614494460747997184: "theres' a double rainbow over the white house URL",
#  615592870540488704: 'if they can light up the white house like a rainbow, it sure as hell better be red, white & blue for independence day.',
#  689661418484994049: '.@arianagrande just created a unisex fragrance named after her brother: URL URL',
#  724603564946010112: 'twenty-five stories proving target’s pro-trans bathroom policy is dangerous URL',
#  714598318333042688: 'top trump strategist resigns, writes revealing open letter: URL',
#  656848877463560192: 'i’m celebrating #backtothefuture day by bemoaning the lack of hoverboards while ignoring the fact that my phone contains all human knowledge',
#  692157602554343424: 'waiting for the new episode of #teenwolf like... URL',
#  765735409984806912: 'trump: dems "failed and betrayed the africanamerican community” trump: “laziness is a trait in blacks, it really is" URL',
#  614610102927147008: "bro there's either a black president in a rainbow whitehouse or i'm having the best trip ever",
#  614650850393391104: 'wow! what a way to end this historic day! URL #lovewins #loveislove #equalityforall #lgbt URL',
#  614648099542204416: 'white house shines rainbow-colored lights in honor of #scotus gay marriage decision #lovewins URL URL',
#  544514564407427072: 'police seem relaxed, suggesting all hostages are out and gunman no longer a threat URL #sydneysiege',
#  707305999971921920: '‘president petty strikes again’: obama will reportedly skip nancy reagan’s funeral,,, ✅ URL URL',
#  644329878876237824: 'alert: tsunami advisory issued for southern california from 3-7 a.m. local time. stay away from ocean and shoreline. #cawx #tsunami',
#  553566026030272512: 'breaking: two hostage situations in france are linked, paris prosecutor says',
#  715253497462145024: 'just in: donald trump to @msnbc: "there has to be some form of punishment" for women who have an abortion.',
#  693804277031157761: 'unstoppable! novak djokovic is now a perfect 6-for-6 in australian open finals after his win over andy murray. URL',
#  715268937873760256: 'donald trump goes full anti-woman: "punishment" for women who abort URL URL',
#  763964234774347776: '.@theweeknd donates $250,000 to black lives matter URL via @cnnent URL',
#  614616994499788800: "there's a rainbow over the white house right now, just the same as when dublin had one the day ireland legalized URL",
#  693185853867294721: 'meet quasimodo, the dog with the short spine URL URL',
#  553506608203169792: 'map shows industrial estate where 2 #charliehebdo suspects are holed up, surrounded by police URL URL',
#  751856580874960897: 'should say "labor unions aligned with @hillaryclinton" stopped dems from saying no tpp-they don\'t speak for nurses URL',
#  712223438698627073: "keith richards 'once pulled a knife on donald trump', claims rolling stones' former promoter URL URL",
#  707405809181917184: 'bachmann: obama "classless" for missing nancy reagan’s funeral URL URL',
#  693013768738115584: "uk heterosexual couple who want to enter civil partnership rather than marry lose challenge at london's high court URL",
#  744390771869102080: 'one of the men who wanted to copy the #orlando shooter was stopped in l.a. he was a liberal democrat and #berniebro. URL',
#  524959809402331137: 'senior u.s. official: canadian government has informed u.s. that one shooter is dead in ottawa. live blog: URL',
#  778689027918618625: 'black men may have cause to run from police, massachusetts high court says URL',
#  707412869860696064: 'bachmann slams "classless" obama for skipping nancy reagan’s funeral URL URL',
#  650710483289419776: 'local school art project titled "candlelight" URL',
#  656523458139045889: 'is your drug dealer charging you more because of the 5p bag charge? let us know! ring 101 now URL',
#  693135382309896192: 'breaking: canada has four recent cases of #zika, all from travelers: public health agency',
#  623533663947517952: 'gay marriage ruling? white house in rainbow colors within hours. 4 murdered marines & a murdered sailor? 5 days to lower the flag. nice.',
#  692833140428017664: '"let\'s not make the next two weeks about a \'black qb.\' let\'s just talk about the greatness of this guy." -c. barkley URL',
#  614599815280857088: 'look: @whitehouse lights up in rainbow colors to celebrate #scotus same-sex marriage ruling URL',
#  693853310479155200: 'meet our new fave celebrity couple: leonardo dicaprio and his vape pen URL URL',
#  614615157730357248: 'watch live: as sun goes down, white house lights up rainbow colors to celebrate scotus ruling URL URL',
#  714851393861881857: "trump's top strategist, stephanie cegielski, has quit his campaign + just wrote an open letter to trump supporters: URL",
#  767859423150759936: 'study links clinical depression to getting dunked on URL URL',
#  764906140257837056: '"my dad is in the air force and that inspired me to have my back up job be president" —lily: URL URL',
#  619242759359037440: 'obama 2008:"i support traditional marriage, christians vote for me" obama 2015:"the white house is a rainbow. bring me my unicorn" merica.',
#  552792913910833152: 'at least 11 dead in shooting at hq of #charliehebdo in #paris (police source) URL',
#  764368020391223296: 'video : clueless hillary clinton calls for americans to respect and empathize with isis URL',
#  741995157969592321: 'orlando shooter, muslim, omar mateen was a registered democrat. URL',
#  767754921403899906: 'of the 54 killed by young suicide bomber at wedding in turkey, 22 were under the age of 14. URL URL',
#  692940257134653441: 'icymi: a dog accidentally stumbled into the middle of a local half marathon ... and earned 7th place. URL',
#  667487418388488192: 'the picture of a syrian child "surrendering" to a camera is real. URL URL',
#  553586897168392192: '#breaking : both charlie hebdo suspects killed as police storm building (police sources) URL URL',
#  730516765525082112: "a canadian teen didn't find a lost mayan city: URL URL",
#  693128224960856064: 'iranian surveillance drone flies over u.s. aircraft carrier in persian gulf URL URL',
#  553221600955621376: "clarissa, 27 years old, police trainee of montrouge police in #france. victim of this morning's attack. via @_batou_ URL",
#  693071538896162816: 'orphanage saved by bikini car wash URL URL',
#  693869818366287872: 'vanessa hudgens\' father, gregory hudgens, dies the night before "grease: live" URL URL',
#  714998347111669760: 'we must address the political marginalization and institutional racism affecting people of color. read my plan: URL',
#  686666933949837312: 'the guardian front page, tuesday 12 january 2016: david bowie 1947-2016 URL',
#  767710042816602112: "powell: don't 'pin' this on me: ex-secretary of state rejects clinton claim he 'told her to use' email server URL",
#  714811995573325828: "an open letter to trump voters from his top strategist: stop supporting him, he doesn't want to win URL",
#  728101712762834944: 'caitlyn jenner about to post nude for cover of sports illustrated.... 😳',
#  544399927045283840: 'nsw police confirm 5 hostages have emerged from #sydneysiege and they are negotiating: "it might take a bit of time" URL',
#  524947674164760577: 'breaking news: new york times is reporting the canadian soldier who was shot has died from their injuries. heartbreaking. #cdnpoli #ableg',
#  701539698452393986: 'the 2016 race: no, the polling doesn’t prove bernie sanders won the hispanic vote in nevada URL',
#  653285570383335424: '5p!!! hell no!!!!!! #5pbagcharge 😵😵 URL',
#  552792802309181440: '#charliehebdo - 11 dead including 2 police in paris shooting. photo @martinbureau1 #afp URL',
#  707310135291416576: "obama to skip nancy reagan's funeral, as he did scalia's. this time, he'll be attending sxsw: URL",
#  693196937172951040: '"i almost started crying ... but i didn\'t want them to make me the crying face instead of jordan." --draymond green URL',
#  614891047886434304: 'the white house was lit up with rainbow lights to celebrate marriage equality: URL URL',
#  525023025792835585: '#ripnathancirillo rt @globeandmail: soldier killed at war memorial identified as cpl. nathan cirillo #ottawashooting URL',
#  765887221736046592: '#whiteliberalproverbs" i\'ll have them n*ggers voting democratic for the next two hundred years". lbj, founder of the modern welfare state',
#  767561970182598657: 'nothing to see here. just nuggets forward wilson chandler catching a 350-pound fish: URL URL',
#  687984820815851521: "jimmy fallon and sesame street characters photobomb families & it's seriously adorable: URL URL",
#  544282227035869184: 'breaking news: gunmen take hostages at sydney cafe, wave islamic flag URL URL',
#  766822417712963584: 'it\'s been 5 years since "what makes you beautiful" lit up our world like nobody else: URL URL',
#  553558982476828674: 'on israeli tv, an israeli woman speaks of her nephew,a mother with 6 month old baby, held hostage in the supermarket in paris. #jesuisjuif',
#  544290258951892992: 'central sydney shut down by police amid ongoing hostage situation: URL',
#  650254360727973889: '5p bag charge fi dead #robthisengland URL',
#  544329935943237632: 'uber sydney trips from cbd will be free for riders. higher rates are still in place to encourage drivers to get into the cbd.',
#  693586539562037248: 'what a rally for no. 1. oklahoma came back from 14 down and won 77-75 at lsu on this late jumper: URL',
#  764497123530375169: 'man armed with knife on swiss train starts fire - seven people hospitalised with knife wounds and burns, police say URL',
#  724939017410727938: '500,000 boycott target over trans bathroom policy... URL',
#  651044059222556674: 'the best thing about the 5p plastic bag charge is that the cupboard next to my sink is now worth £672,348.',
#  552802654641225728: 'charlie hebdo shooting latest: 12 dead and gunmen still at large URL URL',
#  723477822950395904: 'purple pain: landmarks across globe light up in fitting prince tributes #ripprince URL URL',
#  544305540286148609: 'a man believed to be the gunman filmed wearing a black headband inside the cafe URL URL',
#  693906624776245249: "today's the day: if you don't have health insurance, make sure you #getcovered at URL now! URL",
#  524923462398513152: "shots fired on parliament hill after a man walked up with a gun. i'm locked in a security office on parliament hill",
#  763896522790440960: 'layton police officer hospitalized after subway worker serves him meth and thc in his drink (video) URL',
#  616421546702336000: 'woah, nature. URL URL',
#  524944399890124801: 'recap: gunman shot dead inside parliament buildings; police believe there may be others on loose. cdn soldier shot earlier at war memorial.',
#  686657138270277634: 'photos of the day URL URL',
#  544391176137089024: 'hostage taker in sydney cafe demands isis flag and call with australian pm, sky news reports. URL #sydneysiege',
#  524969201102901248: 'mps credit sergeant-at-arms for saving lives in parliament hill shootings URL URL',
#  756690088533393409: '"laziness is a trait in blacks," 1991 book quotes trump as saying: URL URL',
#  767807335691653120: 'these louisiana politicians are demanding flood aid, but voted against sandy relief URL URL',
#  552806757672964097: 'update: 12 now confirmed dead in #charliehebdo attack in paris, @ap is reporting. story: URL (ap) URL',
#  693761289601060864: 'at least 30 people killed in double blast near shia shrine of sayyida zeinab, south of damascus - syrian state media URL',
#  544350567183556608: 'we can see people coming out a firedoor near the lindt cafe to waiting police. 2-3 people. hard to see. #sydneysiege',
#  758825535480864769: 'hillary clinton is lying. clinton is not first woman nominated for president. it was victoria woodhull in 1872. to … URL',
#  707300612862566400: 'obama to skip nancy reagan’s funeral, attend entertainment festival instead URL URL',
#  693080409282846720: '.@potus will make his latest push to advance equal pay for women today URL URL',
#  614593386188828672: 'white house lit in rainbow colors following us supreme court ruling that same-sex couples have right to marry. URL',
#  692665281362202624: "we've devoted 24 pages to #batman v #superman, interviewing @zacksnyder, @benaffleck, henry cavill, @galgadot... URL",
#  767129248045948929: '‘i can’t do this anymore,’ think 320 million americans quietly going about day URL URL',
#  692701223326056449: "we hope you're as excited about thursday as this kid was about lebron's easy basket: URL",
#  732981604826677249: "target says boycott over transgender bathroom policy isn't hurting sales URL",
#  692753210692476928: 'french police still searching for woman who may have been accompanying 28-year-old man arrested at disneyland paris URL',
#  650046859537448960: 'an openly gay man said that he and his partner met with pope francis a day before kim davis did URL',
#  693171092555431936: 'watch: tommy chong made a pro-bernie sanders video URL URL',
#  693546915892428800: 'jeb bush campaign kicks off 3-state farewell tour with iowa town hall meeting URL URL',
#  544269749405097984: "breaking: live coverage of hostage situation unfolding in sydney's martin place URL URL",
#  760109079133990912: '“after school satan clubs”? URL',
#  779633844680962048: "this network of tunnels is from the stone age however no one knows how they could've been constructed at the time URL",
#  765859710503378944: 'top north korean diplomat who disappeared from london embassy has defected to south korea, seoul confirms URL'}

# %%
twitter15_labels
# Out:
# {656955120626880512: 'false',
#  615689290706595840: 'true',
#  613404935003217920: 'false',
#  731166399389962242: 'unverified',
#  714598641827246081: 'unverified',
#  614467824313106432: 'true',
#  715515982584881152: 'unverified',
#  693315824132685824: 'non-rumor',
#  693843042546106369: 'non-rumor',
#  622891631293935616: 'false',
#  692630756548591616: 'non-rumor',
#  693265096278163456: 'non-rumor',
#  553589051044151296: 'true',
#  553590835850514433: 'true',
#  622858454949040128: 'false',
#  656870311057575936: 'false',
#  616311563071434753: 'true',
#  641666167992647681: 'non-rumor',
#  525060425184858112: 'true',
#  672513234419638273: 'false',
#  544382892378714113: 'true',
#  681824512120324096: 'non-rumor',
#  620835698514464768: 'false',
#  626898253900943360: 'false',
#  618804516578680832: 'false',
#  672632899921833984: 'false',
#  553588178687655936: 'true',
#  594687353937100801: 'false',
#  613016993692798977: 'false',
#  663385747177775105: 'false',
#  766715993385267201: 'non-rumor',
#  693141729529184256: 'non-rumor',
#  524966904885428226: 'true',
#  613393657161510913: 'false',
#  544374511194632192: 'true',
#  706665777332621314: 'unverified',
#  693827886021767169: 'non-rumor',
#  604354747357859842: 'false',
#  767709416879644672: 'non-rumor',
#  693146363685642240: 'non-rumor',
#  652783670370115585: 'false',
#  674187250792558592: 'false',
#  726043971911213057: 'unverified',
#  524935485370929152: 'true',
#  730939370765754368: 'unverified',
#  723365789378584578: 'unverified',
#  674244561519161344: 'false',
#  553535829017370625: 'true',
#  731093044460683264: 'unverified',
#  693086218276474880: 'non-rumor',
#  692150118921957376: 'non-rumor',
#  656830586577883136: 'false',
#  553543369604210689: 'true',
#  767814876433571840: 'non-rumor',
#  649985459389661184: 'true',
#  553531413459660800: 'true',
#  693840291992838147: 'non-rumor',
#  663925546812837888: 'false',
#  614604054552018944: 'true',
#  637382230394822656: 'false',
#  661222523275636736: 'false',
#  714531423273746432: 'unverified',
#  675043569367982081: 'false',
#  544314234541469696: 'true',
#  651809229842608128: 'unverified',
#  693140340367187969: 'non-rumor',
#  553534838880608256: 'true',
#  633961125126668288: 'false',
#  544512108885725184: 'true',
#  552805488631758849: 'true',
#  645711628046995462: 'false',
#  614608936491188225: 'true',
#  693858804279201794: 'non-rumor',
#  674014933235859456: 'false',
#  690042063958732800: 'non-rumor',
#  693041285087756288: 'non-rumor',
#  620971220301787136: 'false',
#  656880145769197568: 'false',
#  674263945172119552: 'true',
#  612646796355960832: 'false',
#  544511199702822913: 'true',
#  650952376954650629: 'unverified',
#  693441093048766464: 'non-rumor',
#  553107921081749504: 'true',
#  666190716448587776: 'false',
#  681199637387149313: 'non-rumor',
#  632377165477191680: 'true',
#  652992524504600576: 'false',
#  763738618573623297: 'unverified',
#  672927317191229440: 'false',
#  757367391202471937: 'unverified',
#  688819658057740290: 'non-rumor',
#  692845716826300418: 'non-rumor',
#  756282236375277568: 'unverified',
#  692748411481780224: 'non-rumor',
#  675193315306905600: 'false',
#  674364257799004160: 'false',
#  716461257025581056: 'unverified',
#  662430295254175744: 'false',
#  544512676643500033: 'true',
#  638050997340893184: 'false',
#  692890520960397312: 'non-rumor',
#  544324444773433348: 'true',
#  745236050407194624: 'unverified',
#  673079581520318464: 'false',
#  691995324752252930: 'non-rumor',
#  673984270902427650: 'false',
#  524975705206304769: 'true',
#  618805892222468096: 'false',
#  693086478667112448: 'non-rumor',
#  614595181845839873: 'true',
#  654371696195993600: 'false',
#  665358434351509504: 'false',
#  755439197125767169: 'unverified',
#  666633171325353989: 'false',
#  729647367457230850: 'unverified',
#  726442550266044416: 'unverified',
#  666070802924617728: 'false',
#  544512664769396736: 'true',
#  692106491365605376: 'non-rumor',
#  727966590084485120: 'unverified',
#  691789524498845699: 'non-rumor',
#  767803368081358848: 'non-rumor',
#  667379734343471104: 'false',
#  715671763808493569: 'unverified',
#  653250169752977408: 'false',
#  656361703664451585: 'unverified',
#  643103859729166337: 'false',
#  714560810266132480: 'unverified',
#  658065957823324160: 'false',
#  693534670428971008: 'non-rumor',
#  722885778448121857: 'unverified',
#  614599619310407680: 'true',
#  706933939953344514: 'unverified',
#  691285663522648065: 'non-rumor',
#  661229627734667264: 'false',
#  714755546285477888: 'unverified',
#  672102358516670465: 'non-rumor',
#  673686233936072704: 'false',
#  618192748735299584: 'false',
#  715264793737879553: 'unverified',
#  614594667225571328: 'true',
#  693935557009801218: 'non-rumor',
#  644229386149888001: 'false',
#  763428684850094080: 'unverified',
#  671181758692507648: 'false',
#  692078399012130816: 'non-rumor',
#  752875379765968897: 'unverified',
#  626642648179159040: 'false',
#  742114513726623744: 'unverified',
#  716457799392342018: 'unverified',
#  778625026144792577: 'unverified',
#  614610920782888960: 'true',
#  715254040289021952: 'unverified',
#  673872171341447169: 'false',
#  693167683701968896: 'non-rumor',
#  724624672604610562: 'unverified',
#  655432919595548672: 'unverified',
#  692014905239666688: 'non-rumor',
#  544520042810200064: 'true',
#  692803280238419971: 'non-rumor',
#  664000310856310784: 'false',
#  742571519105077248: 'unverified',
#  767541796410839040: 'non-rumor',
#  641972184412327937: 'true',
#  651321040119963648: 'false',
#  662151653462790144: 'false',
#  693844030589902848: 'non-rumor',
#  676067381299576832: 'false',
#  544491151118860289: 'true',
#  544515538383564801: 'true',
#  673615400655970304: 'false',
#  653432261203750912: 'unverified',
#  641443248909754368: 'false',
#  614601139422633984: 'true',
#  524931324763992064: 'true',
#  707786906189303808: 'unverified',
#  656047932093763584: 'false',
#  723025600810766336: 'non-rumor',
#  656595123590012928: 'false',
#  615346611955183616: 'false',
#  763524712853102596: 'unverified',
#  663817239896821760: 'false',
#  659462980476637184: 'false',
#  669259395902152704: 'false',
#  620367840902782976: 'false',
#  733242244522725376: 'unverified',
#  544301453717041152: 'true',
#  628045645010608128: 'false',
#  672169954016403456: 'false',
#  693076140278153217: 'non-rumor',
#  674314254732931072: 'false',
#  714555825122107392: 'unverified',
#  611039775856812032: 'false',
#  778681502825451520: 'unverified',
#  525068915068923904: 'true',
#  740791134146965504: 'unverified',
#  544504183341064192: 'true',
#  553476490315431937: 'true',
#  761573188543229952: 'non-rumor',
#  673696115305406466: 'false',
#  651825062174195712: 'false',
#  633949800761700352: 'false',
#  761999790892806144: 'non-rumor',
#  553587013409325058: 'true',
#  544513524438155264: 'true',
#  672539897899577344: 'false',
#  693691456222052352: 'non-rumor',
#  693648684857323521: 'non-rumor',
#  655812191233417216: 'unverified',
#  672219174463275008: 'false',
#  614628865353351168: 'true',
#  727854332188577792: 'unverified',
#  544358564484378624: 'true',
#  742012307694223361: 'unverified',
#  707332312724283392: 'unverified',
#  755447443009916929: 'unverified',
#  693555965019492352: 'non-rumor',
#  705092738224525312: 'unverified',
#  724661834419048448: 'unverified',
#  757190314880884736: 'unverified',
#  544278985249550337: 'true',
#  544367462012432384: 'true',
#  775672628493357057: 'unverified',
#  692797856386777089: 'non-rumor',
#  614645853291155457: 'true',
#  682916727282270208: 'non-rumor',
#  725983128444129280: 'unverified',
#  766808183696351233: 'unverified',
#  552791196247269378: 'true',
#  524943490887991296: 'true',
#  667534186450825216: 'false',
#  687643002240679936: 'non-rumor',
#  723511860516016128: 'unverified',
#  677099574855639044: 'false',
#  544391533240516608: 'true',
#  656825206045020160: 'false',
#  525025279803424768: 'true',
#  693119705469587456: 'non-rumor',
#  666051332504207360: 'false',
#  692929779696275456: 'non-rumor',
#  650975967146602496: 'unverified',
#  553544694765215745: 'true',
#  674080899055546368: 'false',
#  626770498328895488: 'false',
#  657007736467525632: 'false',
#  614626710248534016: 'true',
#  751536167183613952: 'unverified',
#  693771953648373760: 'non-rumor',
#  649903655160815616: 'true',
#  692082861525078017: 'non-rumor',
#  614054616154550273: 'false',
#  674301960787505153: 'false',
#  658755852199927808: 'unverified',
#  748543642323783681: 'unverified',
#  614494170590367744: 'true',
#  661870323034431489: 'false',
#  637873886072320001: 'false',
#  732004388181434368: 'unverified',
#  689938201193115648: 'non-rumor',
#  645362146415525888: 'false',
#  692758581494599681: 'non-rumor',
#  672632863452299264: 'false',
#  727187859367546880: 'unverified',
#  764931593303646208: 'unverified',
#  525056576038518785: 'true',
#  672433211604013057: 'false',
#  747275598347837440: 'unverified',
#  774833492865593344: 'unverified',
#  760928376668454912: 'unverified',
#  728013148788154368: 'unverified',
#  614618682543616000: 'true',
#  693060960001597440: 'non-rumor',
#  693826104633737217: 'non-rumor',
#  723644048867774464: 'unverified',
#  742050150307246080: 'unverified',
#  675064077367005184: 'false',
#  524926235030589440: 'true',
#  749286768554438658: 'unverified',
#  544380742076088320: 'true',
#  614605997953404929: 'true',
#  629503919098429440: 'false',
#  692623941131722752: 'non-rumor',
#  626546123713474560: 'false',
#  672906198434209792: 'false',
#  673615263040798726: 'false',
#  647169573599449088: 'false',
#  641050980985999360: 'false',
#  727179214546456577: 'unverified',
#  666107476526432256: 'false',
#  620916279608651776: 'false',
#  673664899571060736: 'false',
#  544271284796784640: 'true',
#  692071267189395457: 'non-rumor',
#  651486105628463105: 'unverified',
#  675065047710892033: 'false',
#  668144671772778497: 'false',
#  604625816992002049: 'false',
#  682996350909157376: 'non-rumor',
#  688752927381581824: 'non-rumor',
#  693087220459270144: 'non-rumor',
#  524962142563610625: 'true',
#  693573781730783232: 'non-rumor',
#  692083780123783172: 'non-rumor',
#  627828211003469825: 'false',
#  693059995013742592: 'non-rumor',
#  614594195479752704: 'true',
#  692691444046372865: 'non-rumor',
#  614593989203886080: 'true',
#  690376107825192960: 'non-rumor',
#  658259426172891136: 'false',
#  676586804242309121: 'unverified',
#  651959206287908868: 'false',
#  681147789653356544: 'true',
#  652882609219833856: 'false',
#  544476808566276097: 'true',
#  687274510643511296: 'non-rumor',
#  647464349611589632: 'false',
#  726086935903494144: 'unverified',
#  691632238035886081: 'non-rumor',
#  524952883343925249: 'true',
#  688021039322894336: 'non-rumor',
#  707308274270539777: 'unverified',
#  691678576018657281: 'non-rumor',
#  692874200927698945: 'non-rumor',
#  666640008149925893: 'false',
#  663515735231062016: 'false',
#  643139873264812032: 'false',
#  689860942671130624: 'non-rumor',
#  656662726014599168: 'false',
#  674229534888185856: 'false',
#  716424773216022530: 'unverified',
#  672432930426372096: 'false',
#  600451916414484480: 'false',
#  692838430783332357: 'non-rumor',
#  717081129627553792: 'unverified',
#  765612862681255936: 'non-rumor',
#  641088973717110784: 'false',
#  652349108653551616: 'unverified',
#  777710439870455808: 'unverified',
#  553508098825261056: 'true',
#  762793077509464064: 'non-rumor',
#  614628136634949632: 'true',
#  580324027715063808: 'true',
#  634665777400950784: 'false',
#  674301413040758785: 'false',
#  613362193787129860: 'false',
#  743764020679741440: 'unverified',
#  692820029159653377: 'non-rumor',
#  693471161313816576: 'non-rumor',
#  716092408920936448: 'unverified',
#  524941132237910016: 'true',
#  727116900983934976: 'unverified',
#  655986243042459648: 'false',
#  544283772569788416: 'true',
#  693818562981421056: 'non-rumor',
#  658938136299511808: 'unverified',
#  618449248179191808: 'false',
#  693897857376632832: 'non-rumor',
#  692410832307818497: 'non-rumor',
#  662381914842603520: 'false',
#  615494435074363392: 'true',
#  763520953619918848: 'unverified',
#  766568413418356736: 'non-rumor',
#  676367888543031296: 'true',
#  692758050378256388: 'non-rumor',
#  642465192408940544: 'true',
#  612438528803213312: 'false',
#  613425834301485056: 'false',
#  714567472712589312: 'unverified',
#  693281966846808064: 'non-rumor',
#  659428447459110912: 'false',
#  672902686380003328: 'false',
#  659439879701602304: 'false',
#  553590459688570880: 'true',
#  525058976376193024: 'true',
#  669201837187334144: 'false',
#  652300118205427716: 'unverified',
#  693203974388895744: 'non-rumor',
#  747443219487678464: 'unverified',
#  755548076438196225: 'unverified',
#  728627623488786433: 'unverified',
#  553476880339599360: 'true',
#  749039299677417472: 'unverified',
#  687537772970684417: 'non-rumor',
#  725070832494624769: 'unverified',
#  728038172270198787: 'unverified',
#  500378223977721856: 'true',
#  724348906096590849: 'unverified',
#  658786161733734400: 'false',
#  728207861050970112: 'unverified',
#  651402689352351744: 'false',
#  634943791934406657: 'false',
#  544319832486064128: 'true',
#  693606934050684928: 'non-rumor',
#  666810213274689537: 'false',
#  692702295281262593: 'non-rumor',
#  692498490249891842: 'non-rumor',
#  689867195657101312: 'non-rumor',
#  553512735192141826: 'true',
#  544517264054423552: 'true',
#  656629493377990656: 'false',
#  663744139666804736: 'unverified',
#  675005503160901632: 'false',
#  638047610973089793: 'false',
#  727623131494387714: 'unverified',
#  723198441690636288: 'non-rumor',
#  641082932740947972: 'true',
#  648894687542034432: 'false',
#  692925396292091905: 'non-rumor',
#  752965545528528898: 'unverified',
#  778572032531427332: 'unverified',
#  716451800581279744: 'unverified',
#  637868242560638980: 'false',
#  498430783699554305: 'true',
#  641430951403343872: 'false',
#  635632641635667968: 'false',
#  652000523525091328: 'unverified',
#  626897206717624320: 'false',
#  693476774462820352: 'non-rumor',
#  626516248206135296: 'false',
#  676094756758364160: 'false',
#  715256242990505984: 'unverified',
#  690650123358093312: 'non-rumor',
#  701514249269542912: 'unverified',
#  623599854661541888: 'true',
#  629209452793626624: 'false',
#  693811101146963968: 'non-rumor',
#  666497286663503872: 'false',
#  642432477185867776: 'false',
#  682999206290829312: 'non-rumor',
#  660466342038867969: 'false',
#  656202544331517952: 'false',
#  727172374999666688: 'unverified',
#  647193820812177408: 'false',
#  723772395211862016: 'unverified',
#  614607711368519680: 'true',
#  656818921979310081: 'false',
#  647168914955243520: 'false',
#  661251968078221312: 'false',
#  690680149164085248: 'non-rumor',
#  665361505303584774: 'false',
#  613294443878305796: 'false',
#  676120162018451456: 'false',
#  665379967757324288: 'false',
#  766752508312166402: 'non-rumor',
#  612741808125120513: 'false',
#  689267711856263168: 'non-rumor',
#  613023744454475776: 'false',
#  614671961801785344: 'true',
#  675490515748425728: 'true',
#  740748123581087745: 'unverified',
#  690580180805509121: 'non-rumor',
#  552984502063337472: 'true',
#  650128194209730561: 'true',
#  612841482823729152: 'false',
#  636925368927064064: 'false',
#  674015148382666752: 'false',
#  656834590779289600: 'false',
#  681767380305985536: 'false',
#  648310692794109952: 'false',
#  524995771587108864: 'true',
#  692752491482615808: 'non-rumor',
#  693502060545703937: 'non-rumor',
#  766789709045518336: 'unverified',
#  652982112870662144: 'unverified',
#  693456187036037123: 'non-rumor',
#  692796451987034113: 'non-rumor',
#  703234354579898368: 'unverified',
#  693466451081060353: 'non-rumor',
#  655815788675399680: 'unverified',
#  552832817089236992: 'true',
#  544291965513134080: 'true',
#  726190016435728385: 'unverified',
#  676870737932742656: 'false',
#  672553813249826816: 'non-rumor',
#  649881917534433280: 'true',
#  692023855926374400: 'non-rumor',
#  725174535897620481: 'unverified',
#  688446106943008768: 'non-rumor',
#  640107106943766528: 'false',
#  748640007934590976: 'unverified',
#  724320681517670400: 'unverified',
#  640644123339431936: 'false',
#  661299012386095105: 'false',
#  613061089518034944: 'false',
#  672424512516964352: 'false',
#  628319096606732290: 'true',
#  524936872666353664: 'true',
#  673611867181473792: 'false',
#  673581371458199552: 'false',
#  668872645589471232: 'false',
#  669613420665159680: 'false',
#  676718762830221312: 'false',
#  613194145423826944: 'false',
#  701175292937707520: 'unverified',
#  544289409294553088: 'true',
#  665575674485211136: 'false',
#  641191076716417025: 'false',
#  682895395077373952: 'non-rumor',
#  553587303172833280: 'true',
#  633823543541768192: 'false',
#  544381485591982083: 'true',
#  766323684076322816: 'non-rumor',
#  691608761128067072: 'non-rumor',
#  614638036593299456: 'true',
#  553587672137334785: 'true',
#  552811386259386370: 'true',
#  672828403016429568: 'false',
#  604642913188872192: 'false',
#  765359928361922560: 'non-rumor',
#  626739062792032256: 'false',
#  663722803489808384: 'false',
#  691719802499432448: 'non-rumor',
#  661120256732041216: 'false',
#  634404792241143809: 'false',
#  524923676484177920: 'true',
#  665364878287224834: 'false',
#  642027433693171712: 'false',
#  626901072209121282: 'false',
#  692735698349199360: 'non-rumor',
#  544277117039837184: 'true',
#  663904307113275392: 'false',
#  544358533819420672: 'true',
#  693528374996652032: 'non-rumor',
#  724703995147751424: 'unverified',
#  759460236042305536: 'unverified',
#  524965775036387329: 'true',
#  673346166822694914: 'false',
#  525025463648137216: 'true',
#  723521076446142465: 'unverified',
#  672488384695279616: 'false',
#  642145732435292160: 'false',
#  757748522481491968: 'unverified',
#  716439952922312704: 'unverified',
#  614604580601597953: 'true',
#  643225207705075716: 'false',
#  654351281260113920: 'false',
#  692540218310803456: 'non-rumor',
#  661102820976930816: 'false',
#  693061713042771968: 'non-rumor',
#  544518335019229184: 'true',
#  614624331717545984: 'true',
#  615840865815298048: 'true',
#  645356735545364480: 'false',
#  693651239486263296: 'non-rumor',
#  544274934835707905: 'true',
#  655080266784968705: 'false',
#  743058135300988932: 'unverified',
#  658462819667615744: 'false',
#  614617234942656512: 'true',
#  778949749156245504: 'unverified',
#  715255507506892800: 'unverified',
#  544271362022338560: 'true',
#  693321561542127616: 'non-rumor',
#  692082592380751874: 'non-rumor',
#  552793679082311680: 'true',
#  693129259334909952: 'non-rumor',
#  648993731169939456: 'unverified',
#  693893182338289664: 'non-rumor',
#  676955015265837056: 'non-rumor',
#  651786568592658433: 'unverified',
#  544319274072817664: 'true',
#  640182854928961536: 'unverified',
#  727588444000526336: 'unverified',
#  628681462976528384: 'true',
#  724044187113512960: 'unverified',
#  650037735579910145: 'true',
#  544289941996326912: 'true',
#  649974380416618496: 'true',
#  688428083540553728: 'non-rumor',
#  701975210044497921: 'unverified',
#  692826642583019521: 'non-rumor',
#  654343805081157633: 'false',
#  742055437932040193: 'unverified',
#  616481759329427456: 'true',
#  613114185505996802: 'false',
#  552785375161499649: 'true',
#  697992796565741569: 'unverified',
#  714577521992343552: 'unverified',
#  760120409429643266: 'unverified',
#  692368829368918017: 'non-rumor',
#  672180526946656256: 'false',
#  687409983139495939: 'non-rumor',
#  767092161716350980: 'non-rumor',
#  693857080193761285: 'non-rumor',
#  623818627054206977: 'false',
#  757450526153900032: 'unverified',
#  728631482722308096: 'unverified',
#  693402634011701248: 'non-rumor',
#  667465205258051584: 'false',
#  524925215235911680: 'true',
#  525028734991343617: 'true',
#  647169726158925824: 'false',
#  780436430732525569: 'unverified',
#  723915846985342976: 'unverified',
#  631388553801564160: 'false',
#  656811196218286080: 'false',
#  674358835675549696: 'true',
#  766541461189832704: 'non-rumor',
#  616765822095261700: 'true',
#  693857551620968448: 'non-rumor',
#  614610364702044164: 'true',
#  693648675772436480: 'non-rumor',
#  524932935137628160: 'true',
#  640967537178472448: 'true',
#  692884886374318081: 'non-rumor',
#  614595106906226688: 'true',
#  693181857261719553: 'non-rumor',
#  693200309955469312: 'non-rumor',
#  525049639016615937: 'true',
#  755475529294352385: 'unverified',
#  692516224245235712: 'non-rumor',
#  707604196812591104: 'unverified',
#  614790312955904000: 'true',
#  765739657908850688: 'unverified',
#  687748306571804672: 'non-rumor',
#  544520273718812672: 'true',
#  748558349139058688: 'unverified',
#  544350712365207552: 'true',
#  688741019979001856: 'non-rumor',
#  614702244001382400: 'true',
#  693641113693884416: 'non-rumor',
#  767861179951648768: 'non-rumor',
#  524925987239120897: 'true',
#  666335363099660288: 'non-rumor',
#  692550140754841603: 'non-rumor',
#  688755462783782912: 'non-rumor',
#  676491949524713473: 'non-rumor',
#  693939356390653952: 'non-rumor',
#  649584608560832513: 'unverified',
#  707321278135463936: 'unverified',
#  716448280201269248: 'unverified',
#  525019752507658240: 'true',
#  745365403237376000: 'unverified',
#  690106189951139840: 'non-rumor',
#  767698691205410816: 'non-rumor',
#  614620298877513729: 'true',
#  654336219447472128: 'unverified',
#  552791578893619200: 'true',
#  614599587362414592: 'true',
#  701872343736520704: 'unverified',
#  693571567377342466: 'non-rumor',
#  649889459836710912: 'true',
#  763430916236640256: 'unverified',
#  688366079396163584: 'non-rumor',
#  524980744658382848: 'true',
#  711994705333112832: 'unverified',
#  544352727971954690: 'true',
#  765779159176077312: 'non-rumor',
#  690969315470868480: 'non-rumor',
#  705093513076015104: 'unverified',
#  755523157700648960: 'unverified',
#  742678930516123650: 'unverified',
#  614594259900080128: 'true',
#  614614133410033664: 'true',
#  544278335455776769: 'true',
#  665309822208729088: 'non-rumor',
#  732971411157880832: 'unverified',
#  693466724822323200: 'non-rumor',
#  651018580989972480: 'true',
#  727982226290442240: 'unverified',
#  667073349974102017: 'true',
#  524922729485848576: 'true',
#  668849913678209024: 'true',
#  692743102432346113: 'non-rumor',
#  778299287293816832: 'unverified',
#  714503380476026880: 'unverified',
#  689915847939219456: 'non-rumor',
#  728625967921401856: 'unverified',
#  524925050739490816: 'true',
#  628336948810268673: 'true',
#  689890946683576322: 'non-rumor',
#  767459987476054016: 'non-rumor',
#  767203096472719364: 'non-rumor',
#  689641419825242112: 'non-rumor',
#  692393375891361794: 'non-rumor',
#  552783667052167168: 'true',
#  552834961762709505: 'true',
#  716416753409081344: 'unverified',
#  707420972173955072: 'unverified',
#  780882510645370880: 'unverified',
#  553160652567498752: 'true',
#  544268732046913536: 'true',
#  767855091109863424: 'non-rumor',
#  692911086920667136: 'non-rumor',
#  544282005941530624: 'true',
#  614609560658161664: 'true',
#  580348081100734464: 'true',
#  723504069814444033: 'unverified',
#  553586860334010368: 'true',
#  640118021101604864: 'unverified',
#  688751061503442944: 'non-rumor',
#  778530869208190976: 'unverified',
#  544291804057960448: 'true',
#  688004802245214208: 'non-rumor',
#  743126914794037248: 'unverified',
#  653432177632387072: 'unverified',
#  628604055644934144: 'true',
#  692163879909064704: 'non-rumor',
#  728273551883534336: 'unverified',
#  524942470472548352: 'true',
#  552792544132997121: 'true',
#  727834854931435522: 'unverified',
#  544289311504355328: 'true',
#  614494460747997184: 'true',
#  615592870540488704: 'true',
#  689661418484994049: 'non-rumor',
#  724603564946010112: 'unverified',
#  714598318333042688: 'unverified',
#  656848877463560192: 'non-rumor',
#  692157602554343424: 'non-rumor',
#  765735409984806912: 'unverified',
#  614610102927147008: 'true',
#  614650850393391104: 'true',
#  614648099542204416: 'true',
#  544514564407427072: 'true',
#  707305999971921920: 'unverified',
#  644329878876237824: 'non-rumor',
#  553566026030272512: 'true',
#  715253497462145024: 'unverified',
#  693804277031157761: 'non-rumor',
#  715268937873760256: 'unverified',
#  763964234774347776: 'non-rumor',
#  614616994499788800: 'true',
#  693185853867294721: 'non-rumor',
#  553506608203169792: 'true',
#  751856580874960897: 'unverified',
#  712223438698627073: 'unverified',
#  707405809181917184: 'unverified',
#  693013768738115584: 'non-rumor',
#  744390771869102080: 'unverified',
#  524959809402331137: 'true',
#  778689027918618625: 'unverified',
#  707412869860696064: 'unverified',
#  650710483289419776: 'unverified',
#  656523458139045889: 'unverified',
#  693135382309896192: 'non-rumor',
#  623533663947517952: 'true',
#  692833140428017664: 'non-rumor',
#  614599815280857088: 'true',
#  693853310479155200: 'non-rumor',
#  614615157730357248: 'true',
#  714851393861881857: 'unverified',
#  767859423150759936: 'non-rumor',
#  764906140257837056: 'non-rumor',
#  619242759359037440: 'true',
#  552792913910833152: 'true',
#  764368020391223296: 'unverified',
#  741995157969592321: 'unverified',
#  767754921403899906: 'non-rumor',
#  692940257134653441: 'non-rumor',
#  667487418388488192: 'true',
#  553586897168392192: 'true',
#  730516765525082112: 'unverified',
#  693128224960856064: 'non-rumor',
#  553221600955621376: 'true',
#  693071538896162816: 'non-rumor',
#  693869818366287872: 'non-rumor',
#  714998347111669760: 'unverified',
#  686666933949837312: 'non-rumor',
#  767710042816602112: 'non-rumor',
#  714811995573325828: 'unverified',
#  728101712762834944: 'unverified',
#  544399927045283840: 'true',
#  524947674164760577: 'true',
#  701539698452393986: 'unverified',
#  653285570383335424: 'unverified',
#  552792802309181440: 'true',
#  707310135291416576: 'unverified',
#  693196937172951040: 'non-rumor',
#  614891047886434304: 'true',
#  525023025792835585: 'true',
#  765887221736046592: 'unverified',
#  767561970182598657: 'non-rumor',
#  687984820815851521: 'non-rumor',
#  544282227035869184: 'true',
#  766822417712963584: 'non-rumor',
#  553558982476828674: 'true',
#  544290258951892992: 'true',
#  650254360727973889: 'unverified',
#  544329935943237632: 'true',
#  693586539562037248: 'non-rumor',
#  764497123530375169: 'non-rumor',
#  724939017410727938: 'unverified',
#  651044059222556674: 'unverified',
#  552802654641225728: 'true',
#  723477822950395904: 'unverified',
#  544305540286148609: 'true',
#  693906624776245249: 'non-rumor',
#  524923462398513152: 'true',
#  763896522790440960: 'unverified',
#  616421546702336000: 'true',
#  524944399890124801: 'true',
#  686657138270277634: 'non-rumor',
#  544391176137089024: 'true',
#  524969201102901248: 'true',
#  756690088533393409: 'unverified',
#  767807335691653120: 'non-rumor',
#  552806757672964097: 'true',
#  693761289601060864: 'non-rumor',
#  544350567183556608: 'true',
#  758825535480864769: 'unverified',
#  707300612862566400: 'unverified',
#  693080409282846720: 'non-rumor',
#  614593386188828672: 'true',
#  692665281362202624: 'non-rumor',
#  767129248045948929: 'non-rumor',
#  692701223326056449: 'non-rumor',
#  732981604826677249: 'unverified',
#  692753210692476928: 'non-rumor',
#  650046859537448960: 'true',
#  693171092555431936: 'non-rumor',
#  693546915892428800: 'non-rumor',
#  544269749405097984: 'true',
#  760109079133990912: 'unverified',
#  779633844680962048: 'unverified',
#  765859710503378944: 'non-rumor'}

# %%
len(twitter15_text)
# Out:
# 818

# %% [markdown]
# # Text Only Baseline

# %%
def preprocess(text):
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.EMOJI ,p.OPT.HASHTAG)
    return p.tokenize(text).split()

# %%
def indexer(split_text):
    sent2idx = []
    for w in split_text:
        if w.lower() in word2idx:
            sent2idx.append(word2idx[w.lower()])
        else:
            sent2idx.append(word2idx['_UNK'])
            
    return sent2idx

# %%
def trainModelWithKfold(foldnum,datadir):
    '''
    STEP 1: LOADING DATASET
    '''

    labels = {'true':0,'false':1,'unverified':2,'non-rumor':3}

    data = list(twitter15_text.keys())

    train_ids, valid_ids = kfold_df[foldnum]

    train_text = [twitter15_text[x] for x in train_ids]
    valid_text = [twitter15_text[x] for x in valid_ids]

    train = pd.DataFrame({'text_id':train_ids ,'raw_text':train_text})
    train['clean_text'] = train.raw_text.apply(lambda x: preprocess(x.strip()))

    valid = pd.DataFrame({'text_id':valid_ids ,'raw_text':valid_text})
    valid['clean_text'] = valid.raw_text.apply(lambda x: preprocess(x.strip()))

    words = Counter()
    for sent in tqdm(train.clean_text.values):
        words.update(w.lower() for w in sent)

    for sent in tqdm(valid.clean_text.values):
        words.update(w.lower() for w in sent)

    # sort with most frequently occuring words first
    words = sorted(words, key=words.get, reverse=True)
    # add <pad> and <unk> token to vocab which will be used later
    words = ['_PAD','_UNK'] + words
    print(len(words))

    global word2idx
    word2idx = {o:i for i,o in enumerate(words)}
    idx2word = {i:o for i,o in enumerate(words)}

    train['sentence2idx'] = train.clean_text.apply(lambda x: indexer(x))
    train['length'] = train.clean_text.apply(lambda x: len(x))
    train['label'] = train.text_id.apply(lambda x: labels[twitter15_labels[x]])

    valid['sentence2idx'] = valid.clean_text.apply(lambda x: indexer(x))
    valid['length'] = valid.clean_text.apply(lambda x: len(x))
    valid['label'] = valid.text_id.apply(lambda x: labels[twitter15_labels[x]])
    
    train_loader = VectorizeData(train)
    valid_loader = VectorizeData(valid)
    
    global tl,vl
    tl = DataLoader(dataset=train_loader, batch_size=100, shuffle=True)
    vl = DataLoader(dataset=valid_loader, batch_size=100, shuffle=False)

    vocab_size = len(words)
    embedding_dim = 256
    n_hidden = 50
    n_out = 4
    num_layers = 1
    rnnType = 'gru'

    # n_hiddens = [5,25,50,100,200]
    # n_layers = [1,2,3]
    n_hiddens = [50]
    n_layers = [1]

    rnnTypes = ['gru','lstm']
    bidirTypes = [False,True]

    if torch.cuda.is_available():
        device = 'cuda:1'
    else:
        device = 'cpu'

    results = {}

#     print(vocab_size)
    for bidirType in bidirTypes:
        for n_hidden in n_hiddens:
            for num_layers in n_layers:
                for rnnType in rnnTypes:
                    key = (n_hidden,num_layers,rnnType,bidirType)
    #                 acc,f1 = train(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidirType,rnnType,device,0)
                    cr = trainModel(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidirType,rnnType,device,1,foldnum)
                    with open(datadir+cr['modelname']+'.json', 'a') as fp:
                        json.dump(cr, fp)
                        fp.write('\n')

#                     results[key] = (acc,f1)

    results
    return results

# %%
class VectorizeData(Dataset):
    def __init__(self, df, maxlen=30):
        self.maxlen = maxlen
        self.df = df
#         print('Padding')
        self.df['padded_text'] = self.df.sentence2idx.apply(lambda x: self.pad_data(x))
        
    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self, idx):
#         lens = self.df.length[idx]
        X = self.df.padded_text[idx]
        y = self.df.label[idx]
        lens = self.df.length[idx]
        return X,y,lens
    
    def pad_data(self, s):
        padded = np.zeros((self.maxlen,), dtype=np.int64)
        if len(s) > self.maxlen: padded[:] = s[:self.maxlen]
        else: padded[:len(s)] = s
        return padded

# %% [markdown]
# ## RecModel and RecAttnArchitecture

# %%
class RecArch(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers, bidir, rnnType,device):
        super(RecArch, self).__init__()
        
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers
        self.device = device
        self.rnnType = rnnType
        self.bidirectional = bidir
        
        if self.bidirectional:
            self.numDirs = 2
        else:
            self.numDirs = 1
        
        self.emb = nn.Embedding(self.vocab_size, embedding_dim)
        
        if self.rnnType == 'lstm':
            self.recNN = nn.LSTM(embedding_dim,hidden_dim, num_layers,batch_first=True,bidirectional=self.bidirectional)
            
        if self.rnnType == 'gru':
            self.recNN = nn.GRU(embedding_dim, hidden_dim, num_layers, batch_first=True,bidirectional=self.bidirectional)
            
        if self.rnnType == 'rnn':
            self.recNN = nn.RNN(embedding_dim, hidden_dim, num_layers, batch_first=True, nonlinearity='tanh',bidirectional=self.bidirectional)
        
        self.fc = nn.Linear(self.numDirs*hidden_dim,output_dim)
    
    def forward(self,x):
        embs = self.emb(x)
        embs = embs.view(x.size(0),-1,self.embedding_dim).to(self.device)
        
        h0 = Variable(torch.zeros(self.numDirs*self.num_layers,x.size(0),self.hidden_dim),requires_grad=True).to(self.device)
        
        if self.rnnType == 'lstm':        
            c0 = Variable(torch.zeros(self.numDirs*self.num_layers,x.size(0),self.hidden_dim),requires_grad=True).to(self.device)
            
            out,(hn,cn) = self.recNN(embs,(h0,c0))
        
        else:
            out, hn = self.recNN(embs, h0)
        
#         print(out[:,-1,:].shape)
        out = self.fc(out[:, -1, :])
        return out

# %%
class RecAttnArch(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers, bidir, rnnType, attnType,device):
        super(RecAttnArch, self).__init__()
        
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers
        self.device = device
        self.rnnType = rnnType
        self.attnType = attnType
        self.bidirectional = bidir
        
        if self.bidirectional:
            self.numDirs = 2
        else:
            self.numDirs = 1
        
        self.emb = nn.Embedding(self.vocab_size, embedding_dim)
        
        if self.rnnType == 'lstm':
            self.recNN = nn.LSTM(embedding_dim,hidden_dim, num_layers,batch_first=True,bidirectional=self.bidirectional)
            
        if self.rnnType == 'gru':
            self.recNN = nn.GRU(embedding_dim, hidden_dim, num_layers, batch_first=True,bidirectional=self.bidirectional)
            
        if self.rnnType == 'rnn':
            self.recNN = nn.RNN(embedding_dim, hidden_dim, num_layers, batch_first=True, nonlinearity='tanh',bidirectional=self.bidirectional)
        
        self.query_vector = nn.Parameter(torch.rand(hidden_dim*self.numDirs,1)).float()
        
        self.attnWgtMatrixSize = [self.numDirs*self.hidden_dim, self.numDirs*self.hidden_dim]
        self.attnWgtMatrix = nn.Parameter(torch.randn(self.attnWgtMatrixSize).float()) # Multiplicative Attention
    
        self.softmax = nn.Softmax(dim=1)
        
        if self.attnType == 'dot':
            self.fc = nn.Linear(self.numDirs*self.hidden_dim, output_dim)
        
        if self.attnType == 'self':
            self.fc = nn.Linear(self.numDirs*30*self.hidden_dim, output_dim)
    
    
    def forward(self,x,encMode=False):
        embs = self.emb(x)
        embs = embs.view(x.size(0),-1,self.embedding_dim).to(self.device)
        
        h0 = Variable(torch.zeros(self.numDirs*self.num_layers,x.size(0),self.hidden_dim),requires_grad=True).to(self.device)
        
        if self.rnnType == 'lstm':        
            c0 = Variable(torch.zeros(self.numDirs*self.num_layers,x.size(0),self.hidden_dim),requires_grad=True).to(self.device)
            
            out,(hn,cn) = self.recNN(embs,(h0,c0))
        
        else:
            out, hn = self.recNN(embs, h0)
        
        if self.attnType == 'dot':
            Hw = out
            attn_weights = self.softmax(Hw.matmul(self.query_vector))

            out = out.mul(attn_weights)
            context_vector = torch.sum(out,dim=1)
            
            fc_out = context_vector
            
        if self.attnType == 'self':
            queryMatrix = out
            keyMatrix = out.permute(0,2,1)
            
            attnScores = torch.bmm( torch.matmul(queryMatrix,self.attnWgtMatrix), keyMatrix )
            attnScores = F.softmax(attnScores, dim=2)
            hidden_matrix = torch.bmm(attnScores, queryMatrix)
            
            fc_out = hidden_matrix.view(-1, hidden_matrix.size()[1]*hidden_matrix.size()[2])
        
        if encMode:
            return fc_out
            
        else:
            return self.fc(fc_out)

# %% [markdown]
# #### Baseline

# %% [markdown]
# vocab_size = len(words)
# embedding_dim = 256
# n_hidden = 50
# n_out = 4
# num_layers = 1
# rnnType = 'gru'
# bidir = True
#
# if torch.cuda.is_available():
#     device = 'cuda:2'
#
# else:
#     device = 'cpu'
#
# model = RecAttnArch(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidir,rnnType,device)
# model.to(device)
# model.float()

# %% [markdown]
# optimizer = torch.optim.Adagrad(model.parameters(),lr=0.01)
# # criterion = torch.nn.BCEWithLogitsLoss()
# criterion = torch.nn.CrossEntropyLoss()
#
# count = 0
# seq_dim = 30
# num_epochs = 200
#
# train_losses_iterwise = []
# recall_iterwise = []
# precision_iterwise = []
# accuracy_iterwise = []
# f1score_iterwise = []
# val_losses_iterwise = []
#
# for epoch in tqdm(range(num_epochs)):
#     train_losses = []
#     val_losses = []
#     for i, (text,label,lengths) in enumerate(tl):
#
#         text = Variable(text.view(-1, seq_dim, 1)).to(device)
#         label = Variable(label).to(device)
#
# #         print(sexism_label)
#
#         optimizer.zero_grad()
#         outputs = model(text)
#
# #         print(outputs)
#
#         loss = criterion(outputs, label)
#         train_losses.append(loss.data.cpu())
#
#         loss.backward()
#         optimizer.step()
#         count += 1
#
#         if count % 50 == 0:
#             correct = 0
#             total = 0
#
#             allLabels = []
#             allPreds = []
#
#             for i, (text,label,lengths) in enumerate(vl):
#                 labels=[]
#                 text = Variable(text.view(-1, seq_dim, 1)).to(device)
#                 label = Variable(label).to(device)
#
#                 predicted = model(text)
#                 predicted =  torch.softmax(predicted,1)
#                 predicted = torch.max(predicted, 1)[1].cpu().numpy().tolist()
# #                 print(predicted)
# #                 print(sexism_label)
#                 allLabels += (label.cpu().numpy().tolist())
#                 allPreds += (predicted)
#
#             valacc = accuracy_score(allLabels, allPreds)
#             recscore = recall_score(allLabels, allPreds,average='macro')
#             precscore = precision_score(allLabels, allPreds,average='macro')
#             f1score = f1_score(allLabels, allPreds,average='macro')
#             cr = classification_report(allLabels, allPreds)
#             print(f'acc: {valacc} recall {recscore} prec: {precscore} f1: {f1score}')
#             print(cr)
#
#             train_losses_iterwise.append(np.mean(train_losses))

# %% [markdown]
# ### Optimal combination seems to be with GRU of 50 units and 1 layer and LSTM of 200 units and 1 layer

# %% [markdown]
# vocab_size = len(words)
# embedding_dim = 256
# n_hidden = 100
# n_out = 4
# num_layers = 1
# bidir = False
# rnnType = 'gru'
#
# if torch.cuda.is_available():
#     device = 'cuda:1'
# else:
#     device = 'cpu'
#
# model = RecArch(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidir,rnnType,device)
# model.to(device)
# model.float()
#
# optimizer = torch.optim.Adam(model.parameters(),lr=0.01)
# # criterion = torch.nn.BCEWithLogitsLoss()
# criterion = torch.nn.CrossEntropyLoss()
#
# count = 0
# seq_dim = 30
# num_epochs = 200
#
# train_losses_iterwise = []
# recall_iterwise = []
# precision_iterwise = []
# accuracy_iterwise = []
# f1score_iterwise = []
# val_losses_iterwise = []
#
# for epoch in tqdm(range(num_epochs)):
#     train_losses = []
#     val_losses = []
#     for i, (text,label,lengths) in enumerate(tl):
#         text = Variable(text.view(-1, seq_dim, 1)).to(device)
#         label = Variable(label).to(device)
#
# #         print(sexism_label)
#
#         optimizer.zero_grad()
#         outputs = model(text)
#
# #         print(outputs)
#
#         loss = criterion(outputs, label)
#         train_losses.append(loss.data.cpu())
#
#         loss.backward()
#         optimizer.step()
#         count += 1
#
#         if count % 50 == 0:
#             correct = 0
#             total = 0
#
#             allLabels = []
#             allPreds = []
#
#             for i, (text,label,lengths) in enumerate(vl):
#                 labels=[]
#                 text = Variable(text.view(-1, seq_dim, 1)).to(device)
#                 label = Variable(label).to(device)
#
#                 predicted = model(text)
#                 predicted =  torch.softmax(predicted,1)
#                 predicted = torch.max(predicted, 1)[1].cpu().numpy().tolist()
# #                 print(predicted)
# #                 print(sexism_label)
#                 allLabels += (label.cpu().numpy().tolist())
#                 allPreds += (predicted)
#
#             valacc = accuracy_score(allLabels, allPreds)
#             recscore = recall_score(allLabels, allPreds,average='macro')
#             precscore = precision_score(allLabels, allPreds,average='macro')
#             f1score = f1_score(allLabels, allPreds,average='macro')
#             cr = classification_report(allLabels, allPreds)
#             print(f'acc: {valacc} recall {recscore} prec: {precscore} f1: {f1score}')
#             print(cr)
#
#             train_losses_iterwise.append(np.mean(train_losses))

# %% [markdown]
# torch.save({'state_dict': model.state_dict()}, './gruTextEnc_twit16.pth')

# %% [markdown]
# vocab_size

# %%
def trainModel(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidir,rnnType,device,returncr,foldnum):
#     model = RecAttnArch(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidir,rnnType,'self',device)
    maxAcc = 0
    model = RecArch(vocab_size,embedding_dim,n_hidden,n_out,num_layers,bidir,rnnType,device)
    model.to(device)
    model.float()
    
    modelname = rnnType
#     modelname = rnnType + 'withAttention'
    if bidir:
        modelname = 'Bi'+modelname
    
    optimizer = torch.optim.Adagrad(model.parameters(),lr=0.01)
    # criterion = torch.nn.BCEWithLogitsLoss()
    criterion = torch.nn.CrossEntropyLoss()

    count = 0
    seq_dim = 30
    num_epochs = 300

    train_losses_iterwise = []
    recall_iterwise = []
    precision_iterwise = []
    accuracy_iterwise = []
    f1score_iterwise = []
    val_losses_iterwise = []

    for epoch in tqdm(range(num_epochs)):
        train_losses = []
        val_losses = []
        for i, (text,label,lengths) in enumerate(tl):

            text = Variable(text.view(-1, seq_dim, 1)).to(device)
            label = Variable(label).to(device)

    #         print(sexism_label)

            optimizer.zero_grad()
            outputs = model(text)

    #         print(outputs)

            loss = criterion(outputs, label)
            train_losses.append(loss.data.cpu())

            loss.backward()
            optimizer.step()
            count += 1

            if count % 100 == 0:    
                correct = 0
                total = 0

                allLabels = []
                allPreds = []

                for i, (text,label,lengths) in enumerate(vl):
                    labels=[]
                    text = Variable(text.view(-1, seq_dim, 1)).to(device)
                    label = Variable(label).to(device)

                    predicted = model(text)
                    predicted =  torch.softmax(predicted,1)
                    predicted = torch.max(predicted, 1)[1].cpu().numpy().tolist()
    #                 print(predicted)
    #                 print(sexism_label)
                    allLabels += (label.cpu().numpy().tolist())
                    allPreds += (predicted)

                valacc = accuracy_score(allLabels, allPreds)
                recscore = recall_score(allLabels, allPreds,average='macro')
                precscore = precision_score(allLabels, allPreds,average='macro')
                f1score = f1_score(allLabels, allPreds,average='macro')
                cr = classification_report(allLabels, allPreds,output_dict=True)
                cr['acc'] = valacc
                cr['modelname'] = modelname
                cr['fold'] = foldnum
                
                if cr['acc'] > maxAcc:
                    maxAcc = cr['acc']
                    print(cr['acc'])
                    print(vocab_size)
                         
                    torch.save({'state_dict': model.state_dict()}, './twitter15_kfold_results/'+modelname+'_'+str(foldnum)+'.pth')
                
                accuracy_iterwise.append(valacc)
                f1score_iterwise.append(f1score)
#                 print(f'acc: {valacc} recall {recscore} prec: {precscore} f1: {f1score}')
#                 print(cr)

                train_losses_iterwise.append(np.mean(train_losses))
    
    if returncr:
        print(modelname)
        print(cr)
        return cr
    
    return max(accuracy_iterwise),max(f1score_iterwise)

# %%
for i in range(0,4):
    trainModelWithKfold(i,datadir)
# Out:
# HBox(children=(IntProgress(value=0, max=613), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=205), HTML(value='')))
# 3702
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.6195121951219512
# 3702
# 0.6390243902439025
# 3702
# 0.6536585365853659
# 3702
#
# gru
# {'0': {'precision': 0.639344262295082, 'recall': 0.8863636363636364, 'f1-score': 0.742857142857143, 'support': 44}, '1': {'precision': 0.7169811320754716, 'recall': 0.5135135135135135, 'f1-score': 0.5984251968503936, 'support': 74}, '2': {'precision': 0.6111111111111112, 'recall': 0.7674418604651163, 'f1-score': 0.6804123711340206, 'support': 43}, '3': {'precision': 0.4864864864864865, 'recall': 0.4090909090909091, 'f1-score': 0.44444444444444453, 'support': 44}, 'micro avg': {'precision': 0.624390243902439, 'recall': 0.624390243902439, 'f1-score': 0.624390243902439, 'support': 205}, 'macro avg': {'precision': 0.6134807479920378, 'recall': 0.6441024798582938, 'f1-score': 0.6165347888215005, 'support': 205}, 'weighted avg': {'precision': 0.6286387048670815, 'recall': 0.624390243902439, 'f1-score': 0.6135730066681067, 'support': 205}, 'acc': 0.624390243902439, 'modelname': 'gru', 'fold': 0}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.375609756097561
# 3702
# 0.5756097560975609
# 3702
# 0.6097560975609756
# 3702
# 0.6487804878048781
# 3702
# 0.6585365853658537
# 3702
# 0.6634146341463415
# 3702
# 0.6682926829268293
# 3702
# 0.6731707317073171
# 3702
#
# lstm
# {'0': {'precision': 0.8048780487804879, 'recall': 0.75, 'f1-score': 0.7764705882352942, 'support': 44}, '1': {'precision': 0.7123287671232876, 'recall': 0.7027027027027027, 'f1-score': 0.7074829931972789, 'support': 74}, '2': {'precision': 0.6304347826086957, 'recall': 0.6744186046511628, 'f1-score': 0.651685393258427, 'support': 43}, '3': {'precision': 0.4666666666666667, 'recall': 0.4772727272727273, 'f1-score': 0.4719101123595506, 'support': 44}, 'micro avg': {'precision': 0.6585365853658537, 'recall': 0.6585365853658537, 'f1-score': 0.6585365853658537, 'support': 205}, 'macro avg': {'precision': 0.6535770662947845, 'recall': 0.6510985086566481, 'f1-score': 0.6518872717626376, 'support': 205}, 'weighted avg': {'precision': 0.662287765360839, 'recall': 0.6585365853658537, 'f1-score': 0.6600242157701667, 'support': 205}, 'acc': 0.6585365853658537, 'modelname': 'lstm', 'fold': 0}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.6
# 3702
# 0.6097560975609756
# 3702
# 0.6146341463414634
# 3702
# 0.624390243902439
# 3702
#
# Bigru
# {'0': {'precision': 0.6923076923076923, 'recall': 0.8181818181818182, 'f1-score': 0.7500000000000001, 'support': 44}, '1': {'precision': 0.7142857142857143, 'recall': 0.6756756756756757, 'f1-score': 0.6944444444444444, 'support': 74}, '2': {'precision': 0.5384615384615384, 'recall': 0.4883720930232558, 'f1-score': 0.5121951219512196, 'support': 43}, '3': {'precision': 0.4772727272727273, 'recall': 0.4772727272727273, 'f1-score': 0.4772727272727273, 'support': 44}, 'micro avg': {'precision': 0.624390243902439, 'recall': 0.624390243902439, 'f1-score': 0.624390243902439, 'support': 205}, 'macro avg': {'precision': 0.605581918081918, 'recall': 0.6148755785383693, 'f1-score': 0.6084780734170978, 'support': 205}, 'weighted avg': {'precision': 0.6218172071830609, 'recall': 0.624390243902439, 'f1-score': 0.621528190891665, 'support': 205}, 'acc': 0.624390243902439, 'modelname': 'Bigru', 'fold': 0}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.5365853658536586
# 3702
# 0.6146341463414634
# 3702
#
# Bilstm
# {'0': {'precision': 0.6875, 'recall': 0.75, 'f1-score': 0.717391304347826, 'support': 44}, '1': {'precision': 0.7377049180327869, 'recall': 0.6081081081081081, 'f1-score': 0.6666666666666667, 'support': 74}, '2': {'precision': 0.5777777777777777, 'recall': 0.6046511627906976, 'f1-score': 0.5909090909090908, 'support': 43}, '3': {'precision': 0.43137254901960786, 'recall': 0.5, 'f1-score': 0.4631578947368421, 'support': 44}, 'micro avg': {'precision': 0.6146341463414634, 'recall': 0.6146341463414634, 'f1-score': 0.6146341463414634, 'support': 205}, 'macro avg': {'precision': 0.6085888112075433, 'recall': 0.6156898177247014, 'f1-score': 0.6095312391651064, 'support': 205}, 'weighted avg': {'precision': 0.6276341489547972, 'recall': 0.6146341463414634, 'f1-score': 0.6179833609860959, 'support': 205}, 'acc': 0.6146341463414634, 'modelname': 'Bilstm', 'fold': 0}
# HBox(children=(IntProgress(value=0, max=613), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=205), HTML(value='')))
# 3702
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.6731707317073171
# 3702
# 0.6780487804878049
# 3702
# 0.6829268292682927
# 3702
# 0.6878048780487804
# 3702
#
# gru
# {'0': {'precision': 0.5645161290322581, 'recall': 0.8333333333333334, 'f1-score': 0.6730769230769231, 'support': 42}, '1': {'precision': 0.84, 'recall': 0.6774193548387096, 'f1-score': 0.75, 'support': 62}, '2': {'precision': 0.7333333333333333, 'recall': 0.6346153846153846, 'f1-score': 0.6804123711340205, 'support': 52}, '3': {'precision': 0.5833333333333334, 'recall': 0.5714285714285714, 'f1-score': 0.577319587628866, 'support': 49}, 'micro avg': {'precision': 0.6731707317073171, 'recall': 0.6731707317073171, 'f1-score': 0.6731707317073171, 'support': 205}, 'macro avg': {'precision': 0.6802956989247312, 'recall': 0.6791991610539998, 'f1-score': 0.6702022204599525, 'support': 205}, 'weighted avg': {'precision': 0.6951528979805927, 'recall': 0.6731707317073171, 'f1-score': 0.6753138237171429, 'support': 205}, 'acc': 0.6731707317073171, 'modelname': 'gru', 'fold': 1}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.5951219512195122
# 3702
# 0.6439024390243903
# 3702
#
# lstm
# {'0': {'precision': 0.6538461538461539, 'recall': 0.8095238095238095, 'f1-score': 0.7234042553191489, 'support': 42}, '1': {'precision': 0.7213114754098361, 'recall': 0.7096774193548387, 'f1-score': 0.7154471544715446, 'support': 62}, '2': {'precision': 0.6739130434782609, 'recall': 0.5961538461538461, 'f1-score': 0.6326530612244897, 'support': 52}, '3': {'precision': 0.5, 'recall': 0.46938775510204084, 'f1-score': 0.4842105263157895, 'support': 49}, 'micro avg': {'precision': 0.6439024390243903, 'recall': 0.6439024390243903, 'f1-score': 0.6439024390243903, 'support': 205}, 'macro avg': {'precision': 0.6372676681835627, 'recall': 0.6461857075336338, 'f1-score': 0.6389287493327432, 'support': 205}, 'weighted avg': {'precision': 0.6425674546235017, 'recall': 0.6439024390243903, 'f1-score': 0.6408047671892056, 'support': 205}, 'acc': 0.6439024390243903, 'modelname': 'lstm', 'fold': 1}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.6195121951219512
# 3702
#
# Bigru
# {'0': {'precision': 0.5660377358490566, 'recall': 0.7142857142857143, 'f1-score': 0.631578947368421, 'support': 42}, '1': {'precision': 0.6266666666666667, 'recall': 0.7580645161290323, 'f1-score': 0.6861313868613139, 'support': 62}, '2': {'precision': 0.7045454545454546, 'recall': 0.5961538461538461, 'f1-score': 0.6458333333333334, 'support': 52}, '3': {'precision': 0.48484848484848486, 'recall': 0.32653061224489793, 'f1-score': 0.3902439024390244, 'support': 49}, 'micro avg': {'precision': 0.6048780487804878, 'recall': 0.6048780487804878, 'f1-score': 0.6048780487804878, 'support': 205}, 'macro avg': {'precision': 0.5955245854774157, 'recall': 0.5987586722033726, 'f1-score': 0.5884468925005232, 'support': 205}, 'weighted avg': {'precision': 0.6001017445508933, 'recall': 0.6048780487804878, 'f1-score': 0.5940085186718082, 'support': 205}, 'acc': 0.6048780487804878, 'modelname': 'Bigru', 'fold': 1}
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.40487804878048783
# 3702
# 0.45365853658536587
# 3702
# 0.5121951219512195
# 3702
# 0.5902439024390244
# 3702
# 0.6195121951219512
# 3702
# 0.6390243902439025
# 3702
# 0.6487804878048781
# 3702
#
# Bilstm
# {'0': {'precision': 0.9259259259259259, 'recall': 0.5952380952380952, 'f1-score': 0.7246376811594204, 'support': 42}, '1': {'precision': 0.6438356164383562, 'recall': 0.7580645161290323, 'f1-score': 0.6962962962962962, 'support': 62}, '2': {'precision': 0.5, 'recall': 0.8076923076923077, 'f1-score': 0.6176470588235294, 'support': 52}, '3': {'precision': 0.7142857142857143, 'recall': 0.30612244897959184, 'f1-score': 0.42857142857142855, 'support': 49}, 'micro avg': {'precision': 0.6292682926829268, 'recall': 0.6292682926829268, 'f1-score': 0.6292682926829268, 'support': 205}, 'macro avg': {'precision': 0.6960118141624991, 'recall': 0.6167793420097568, 'f1-score': 0.6167881162126686, 'support': 205}, 'weighted avg': {'precision': 0.681983888332034, 'recall': 0.6292682926829268, 'f1-score': 0.6181600001848271, 'support': 205}, 'acc': 0.6292682926829268, 'modelname': 'Bilstm', 'fold': 1}
# HBox(children=(IntProgress(value=0, max=614), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=204), HTML(value='')))
# 3702
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# 0.5980392156862745
# 3702
# 0.6078431372549019
# 3702
# 0.6274509803921569
# 3702
# 0.6372549019607843
# 3702
# 0.6421568627450981
# 3702
# 0.6470588235294118
# 3702
